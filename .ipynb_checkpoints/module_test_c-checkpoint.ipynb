# %%
import tensorflow as tf
import numpy as np
import os
import time
# from datetime import datetime
# import argparse
# import librosa

# %% [markdown]
# ### Input Data: .wav -> Pitch contour (f0s), Harmonic spectral envelope (sps), Aperiodic spectral envelope (aps)

# %%
from utils import *
from ops import *

# %%
import librosa.display
from IPython.display import Audio
# import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# matplotlib.rcParams['figure.figsize'] = (16, 4)

# %%
random_seed = 0
np.random.seed(random_seed)

# %% [markdown]
# ### Autoencoder: Style_Encoder, Content_Encoder, MLP, Decoder, Discriminator

# %%
def Style_Encoder(inputs, style_dim=16, reuse=False, scope='style_encoder'):                                                            # [1, 24, 128] = [batch_size, feature_channel, time]

    inputs = tf.transpose(inputs, perm=[0, 2, 1], name='input_transpose')                                                               # [1, 128, 24] = [batch_size, time, feature_channel]

    with tf.variable_scope(scope, reuse=reuse):

        h1 = conv1d_layer(inputs=inputs, filters=128, kernel_size=15, strides=1, name='h1_conv')                                        # [1, 128, 128]
        h1_gates = conv1d_layer(inputs=inputs, filters=128, kernel_size=15, strides=1, name='h1_conv_gates')
        h1_glu = gated_linear_layer(inputs=h1, gates=h1_gates, name='h1_glu')

        # Downsample
        d1 = downsample1d_block_withoutIN(inputs=h1_glu, filters=256, kernel_size=5, strides=2, name_prefix='downsample1d_block1')      # [1, 64, 256]
        d2 = downsample1d_block_withoutIN(inputs=d1, filters=512, kernel_size=5, strides=2, name_prefix='downsample1d_block2')          # [1, 32, 512]

        d3 = downsample1d_block_withoutIN(inputs=d2, filters=512, kernel_size=3, strides=2, name_prefix='downsample1d_block3')          # [1, 16, 512]
        d4 = downsample1d_block_withoutIN(inputs=d3, filters=512, kernel_size=3, strides=2, name_prefix='downsample1d_block4')          # [1, 8, 512]

        # Global Average Pooling
        p1 = adaptive_avg_pooling(d4)                                                                                                   # [1, 1, 512]
        style = conv1d_layer(inputs=p1, filters=style_dim, kernel_size=1, strides=1, name='SE_logit')                                   # [1, 1, 16]

        return style                                                                                                                    # [1, 1, 16]


def Content_Encoder(inputs, reuse=False, scope='content_encoder'):
    # IN removes the original feature mean and variance that represent important style information
    inputs = tf.transpose(inputs, perm=[0, 2, 1], name='input_transpose')                                                               # [1, 24, 128] = [batch_size, time, feature_channel]

    with tf.variable_scope(scope, reuse=reuse):

        h1 = conv1d_layer(inputs=inputs, filters=128, kernel_size=15, strides=1, name='h1_conv')                                        # [1, 128, 128]
        h1_norm = instance_norm_layer(inputs=h1, name='h1_norm')
        h1_gates = conv1d_layer(inputs=inputs, filters=128, kernel_size=15, strides=1, name='h1_gates')
        h1_norm_gates = instance_norm_layer(inputs=h1_gates, name='h1_norm_gates')
        h1_glu = gated_linear_layer(inputs=h1_norm, gates=h1_norm_gates, name='h1_glu')

        # downsample
        d1 = downsample1d_block(inputs=h1_glu, filters=256, kernel_size=5, strides=2, name_prefix='downsample1d_block1')                # [1, 64, 256]
        d2 = downsample1d_block(inputs=d1, filters=512, kernel_size=5, strides=2, name_prefix='downsample1d_block2')                    # [1, 32, 512]
               
        # Residual blocks
        r1 = residual1d_block(inputs=d2, filters = 512, kernel_size=3, strides=1, name_prefix='residual1d_block1')                      # [1, 32, 512]
        r2 = residual1d_block(inputs=r1, filters = 512, kernel_size=3, strides=1, name_prefix='residual1d_block2')
        r3 = residual1d_block(inputs=r2, filters = 512, kernel_size=3, strides=1, name_prefix='residual1d_block3')
        content = residual1d_block(inputs=r3, filters=512, kernel_size=3, strides=1, name_prefix='residual1d_block4')

        return content                                                                                                                  # [1, 32, 512]


def MLP(style, reuse=False, scope='MLP'):                                                                                               # [1, 1, 16]

    with tf.variable_scope(scope, reuse=reuse):

        x1 = linear(style, 512, scope='linear_1')                                                                                       # [1, 1, 512]
        x1_gates = linear(x1, 512, scope='linear_1_gates')
        x1_glu = gated_linear_layer(inputs=x1, gates=x1_gates, name='x1_glu')

        x2 = linear(x1_glu, 512, scope='linear_2')
        x2_gates = linear(x2, 512, scope='linear_2_gates')
        x2_glu = gated_linear_layer(inputs=x2, gates=x2_gates, name='x2_glu')

        mu = linear(x2_glu, 512, scope='mu')
        sigma = linear(x2_glu, 512, scope='sigma')

        mu = tf.reshape(mu, shape=[-1, 1, 512])                                                                                         # [1, 1, 512]
        sigma = tf.reshape(sigma, shape=[-1, 1, 512])                                                                                   # [1, 1, 512]

        return mu, sigma                                                                                                                # [1, 1, 512]


def Decoder(content, style, reuse=False, scope="decoder"):

    with tf.variable_scope(scope, reuse=reuse):

        mu, sigma = MLP(style, reuse)                                                                                                   # [1, 1, 512]
        x = content                                                                                                                     # [1, 32, 512]

        # Adaptive Residual blocks
        r1 = residual1d_block_adaptive(inputs=x, filters=512, mu=mu, sigma=sigma, kernel_size=3, strides=1, name_prefix='residual1d_block1')        # [1, 32, 512]
        r2 = residual1d_block_adaptive(inputs=r1, filters=512, mu=mu, sigma=sigma, kernel_size=3, strides=1, name_prefix='residual1d_block2')
        r3 = residual1d_block_adaptive(inputs=r2, filters=512, mu=mu, sigma=sigma, kernel_size=3, strides=1, name_prefix='residual1d_block3')

        # Upsample
        u1 = upsample1d_block(inputs=r3, filters=512, kernel_size=5, strides=1, shuffle_size=2, name_prefix='upsample1d_block1')        # [1, 64, 512]
        u2 = upsample1d_block(inputs=u1, filters=256, kernel_size=5, strides=1, shuffle_size=2, name_prefix='upsample1d_block2')        # [1, 128, 256]

        # Output
        o1 = conv1d_layer(inputs=u2, filters=24, kernel_size=15, strides=1, name='o1_conv')                                             # [1, 128, 24]
        o2 = tf.transpose(o1, perm=[0, 2, 1], name='output_transpose')                                                                  # [1, 24, 128]

        return o2                                                                                                                       # [1, 24, 128] = [batch_size, feature_channel, time]

# %%
def Discriminator(inputs, reuse=False, scope='discriminator'):

    # inputs = [batch_size, num_features, time]
    # add channel for 2D convolution [batch_size, num_features, time, 1]
    inputs = tf.expand_dims(inputs, -1)                                                                                                 # [1, 24, 128, 1]

    with tf.variable_scope(scope, reuse=reuse):

        h1 = conv2d_layer(inputs=inputs, filters=128, kernel_size=[3, 3], strides=[1, 2], name='h1_conv')                               # [1, 24, 64, 128]
        h1_gates = conv2d_layer(inputs=inputs, filters=128, kernel_size=[3, 3], strides=[1, 2], name='h1_conv_gates')
        h1_glu = gated_linear_layer(inputs=h1, gates=h1_gates, name='h1_glu')

        # Downsample
        d1 = downsample2d_block(inputs=h1_glu, filters=256, kernel_size=[3, 3], strides=[2, 2], name_prefix='downsample2d_block1')      # [1, 12, 32, 256]
        d2 = downsample2d_block(inputs=d1, filters=512, kernel_size=[3, 3], strides=[2, 2], name_prefix='downsample2d_block2')          # [1, 6, 16, 512]
        d3 = downsample2d_block(inputs=d2, filters=1024, kernel_size=[6, 3], strides=[1, 2], name_prefix='downsample2d_block3')         # [1, 6, 8, 1024]

        # Output
        o1 = tf.layers.dense(inputs=d3, units=1, activation=tf.nn.sigmoid)

        return [o1]                                                                                                                       # [1, 6, 8, 1]

# %% [markdown]
# ### Autoencoder Model

# %%
##################################################################################
# Model
##################################################################################

def Encoder_A(x_A, reuse=False):
    style_A = Style_Encoder(x_A, reuse=reuse, scope='style_encoder_A')
    content_A = Content_Encoder(x_A, reuse=reuse, scope='content_encoder_A')

    return content_A, style_A

def Encoder_B(x_B, reuse=False):
    style_B = Style_Encoder(x_B, reuse=reuse, scope='style_encoder_B')
    content_B = Content_Encoder(x_B, reuse=reuse, scope='content_encoder_B')

    return content_B, style_B

def Decoder_A(content_B, style_A, reuse=False):
    x_ba = Decoder(content=content_B, style=style_A, reuse=reuse, scope='decoder_A')

    return x_ba

def Decoder_B(content_A, style_B, reuse=False):
    x_ab = Decoder(content=content_A, style=style_B, reuse=reuse, scope='decoder_B')

    return x_ab

def discriminate_real(x_A, x_B):
    real_A_logit = Discriminator(x_A, scope="discriminator_A")
    real_B_logit = Discriminator(x_B, scope="discriminator_B")

    return real_A_logit, real_B_logit

def discriminate_fake(x_ba, x_ab):
    fake_A_logit = Discriminator(x_ba, reuse=True, scope="discriminator_A")
    fake_B_logit = Discriminator(x_ab, reuse=True, scope="discriminator_B")

    return fake_A_logit, fake_B_logit

# %% [markdown]
# ## Module: EmoMUNIT

# %%
class EmoMUNIT(object):
    def __init__(self, sess):
        
        self.train_A_dir = './../../../Database/Emotion/ang_neu/ang'
        self.train_B_dir = './../../../Database/Emotion/ang_neu/neu'
        self.validation_A_dir = './../../../Database/Emotion/ang_neu/val_ang'
        self.validation_B_dir = './../../../Database/Emotion/ang_neu/val_neu'
#         self.max_samples = 1000
        
        self.batch_size = 1
        self.style_dim = 16
        
        self.Encoder_A = Encoder_A
        self.Encoder_B = Encoder_B
        self.Decoder_A = Decoder_A
        self.Decoder_B = Decoder_B
        self.discriminate_real = discriminate_real
        self.discriminate_fake = discriminate_fake
        
        self.recon_x_cyc_w = 0.0
        self.gan_type = 'lsgan'
        
        self.gan_w = 1.0
        self.recon_x_w = 1.0
        self.recon_s_w = 1.0
        self.recon_c_w = 1.0
        self.recon_x_cyc_w = 0.0
               
        self.audio_len = 128    # = n_frames, time_length
        self.audio_ch = 24      # = num_mcep, num_features
        
        self.direction = 'A2B'
        
        self.model_name = 'EmoMUNIT'
        self.gan_type = 'lsgan'
        self.dataset_name = 'ang2neu'
        self.log_dir = 'logs'
        self.sample_dir = 'samples'
        self.checkpoint_dir = 'checkpoint'
        self.result_dir = 'results'
        
        self.sess = sess
        self.epoch = 300
        self.iteration = 1000
        self.init_lr_D = 0.0001
        self.init_lr_G = 0.0002
        
        self.sample_freq = 1000
        self.save_freq = 1000
        
        self.sampling_rate = 16000
        self.frame_period = 5.0
        self.num_mcep = 24
        
    
    def build_model(self):
        self.lr_D = tf.placeholder(tf.float32, name='learning_rate_D')
        self.lr_G = tf.placeholder(tf.float32, name='learning_rate_G')
        
        # Iterate from train_data_A and train_data_A
        self.domain_A = tf.placeholder(tf.float32, shape=[self.batch_size, self.audio_ch, self.audio_len], name='domain_a')
        self.domain_B = tf.placeholder(tf.float32, shape=[self.batch_size, self.audio_ch, self.audio_len], name='domain_b')
    
        self.style_a = tf.placeholder(tf.float32, shape=[self.batch_size, 1, self.style_dim], name='style_a')
        self.style_b = tf.placeholder(tf.float32, shape=[self.batch_size, 1, self.style_dim], name='style_b')  
    
        # encode
        content_a, style_a_prime = self.Encoder_A(self.domain_A)
        content_b, style_b_prime = self.Encoder_B(self.domain_B)

        # decode (within domain)
        x_aa = self.Decoder_A(content_B=content_a, style_A=style_a_prime)
        x_bb = self.Decoder_B(content_A=content_b, style_B=style_b_prime)
    
        # decode (cross domain)
        x_ba = self.Decoder_A(content_B=content_b, style_A=self.style_a, reuse=True)
        x_ab = self.Decoder_B(content_A=content_a, style_B=self.style_b, reuse=True)   
    
        # encode again
        content_b_, style_a_ = self.Encoder_A(x_ba, reuse=True)
        content_a_, style_b_ = self.Encoder_B(x_ab, reuse=True)    
    
        # decode again (if needed)
        if self.recon_x_cyc_w > 0 :
            x_aba = self.Decoder_A(content_B=content_a_, style_A=style_a_prime, reuse=True)
            x_bab = self.Decoder_B(content_A=content_b_, style_B=style_b_prime, reuse=True)

            cyc_recon_A = L1_loss(x_aba, self.domain_A)
            cyc_recon_B = L1_loss(x_bab, self.domain_B)

        else :
            cyc_recon_A = 0.0
            cyc_recon_B = 0.0    
      
        real_A_logit, real_B_logit = self.discriminate_real(self.domain_A, self.domain_B)
        fake_A_logit, fake_B_logit = self.discriminate_fake(x_ba, x_ab)   
    
    
        """ Define Loss """
        # Adversarial Loss
        G_ad_loss_a = generator_loss(self.gan_type, fake_A_logit)
        G_ad_loss_b = generator_loss(self.gan_type, fake_B_logit)
    
        # Discrimination Loss (real/fake)
        D_ad_loss_a = discriminator_loss(self.gan_type, real_A_logit, fake_A_logit)
        D_ad_loss_b = discriminator_loss(self.gan_type, real_B_logit, fake_B_logit)
    
        # Reconstruction Loss
        recon_A = L1_loss(x_aa, self.domain_A) # reconstruction
        recon_B = L1_loss(x_bb, self.domain_B) # reconstruction   
    
        # Semi-CycleGAN Loss
        # For style, encourages diverse outputs given different style codes
        recon_style_A = L1_loss(style_a_, self.style_a)
        recon_style_B = L1_loss(style_b_, self.style_b)
    
        # For content, encourages the translated image to preserve semantic content of the input image
        recon_content_A = L1_loss(content_a_, content_a)
        recon_content_B = L1_loss(content_b_, content_b)   
    
        # Attacker Loss
        Generator_A_loss = self.gan_w * G_ad_loss_a + \
                                   self.recon_x_w * recon_A + \
                                   self.recon_s_w * recon_style_A + \
                                   self.recon_c_w * recon_content_A + \
                                   self.recon_x_cyc_w * cyc_recon_A

        Generator_B_loss = self.gan_w * G_ad_loss_b + \
                           self.recon_x_w * recon_B + \
                           self.recon_s_w * recon_style_B + \
                           self.recon_c_w * recon_content_B + \
                           self.recon_x_cyc_w * cyc_recon_B   
    
        # Defender Loss
        Discriminator_A_loss = self.gan_w * D_ad_loss_a
        Discriminator_B_loss = self.gan_w * D_ad_loss_b
    
        # Total Loss
        self.Generator_loss = Generator_A_loss + Generator_B_loss
        self.Discriminator_loss = Discriminator_A_loss + Discriminator_B_loss
    
    
        """ Training Variables """
        t_vars = tf.trainable_variables()
        G_vars = [var for var in t_vars if 'decoder' in var.name or 'encoder' in var.name]
        D_vars = [var for var in t_vars if 'discriminator' in var.name]
    
        self.G_optim = tf.train.AdamOptimizer(self.lr_G, beta1=0.5, beta2=0.999).minimize(self.Generator_loss, var_list=G_vars)
        self.D_optim = tf.train.AdamOptimizer(self.lr_D, beta1=0.5, beta2=0.999).minimize(self.Discriminator_loss, var_list=D_vars)
    
        """" Summary """
        self.all_G_loss = tf.summary.scalar("Generator_loss", self.Generator_loss)
        self.all_D_loss = tf.summary.scalar("Discriminator_loss", self.Discriminator_loss)
        
        self.R_A_loss = tf.summary.scalar("Reconstruction_A_loss", recon_A)
        self.R_B_loss = tf.summary.scalar("Reconstruction_B_loss", recon_B)
        self.recon_style_A = tf.summary.scalar("recon_style_A", recon_style_A)
        self.recon_style_B = tf.summary.scalar("recon_style_B", recon_style_B)        
        self.recon_content_A = tf.summary.scalar("recon_content_A", recon_content_A)
        self.recon_content_B = tf.summary.scalar("recon_content_B", recon_content_B)         
        
        self.G_A_loss = tf.summary.scalar("G_A_loss", Generator_A_loss)
        self.G_B_loss = tf.summary.scalar("G_B_loss", Generator_B_loss)
        self.G_ad_loss_a = tf.summary.scalar("G_ad_loss_a", G_ad_loss_a)
        self.G_ad_loss_b = tf.summary.scalar("G_ad_loss_b", G_ad_loss_b)
        
        self.D_A_loss = tf.summary.scalar("D_A_loss", Discriminator_A_loss)
        self.D_B_loss = tf.summary.scalar("D_B_loss", Discriminator_B_loss)

        self.G_loss = tf.summary.merge([self.R_A_loss, self.R_B_loss, self.recon_style_A, self.recon_style_B, self.recon_content_A, self.recon_content_B, self.G_ad_loss_a, self.G_ad_loss_b, self.G_A_loss, self.G_B_loss, self.all_G_loss])
        self.D_loss = tf.summary.merge([self.D_A_loss, self.D_B_loss, self.all_D_loss])
    
    
        """ Speech: real and fake """
        self.real_A = self.domain_A
        self.real_B = self.domain_B

        self.fake_A = x_ba
        self.fake_B = x_ab 
    
        """ Test Variables """
        self.test_domain_A = tf.placeholder(tf.float32, [1, self.audio_ch, None], name='test_domain_a') # [1 24 None]
        self.test_domain_B = tf.placeholder(tf.float32, [1, self.audio_ch, None], name='test_domain_b') # [1 24 None]
        
        self.test_style_a = tf.placeholder(tf.float32, [1, 1, self.style_dim], name='test_style_a')   # [1 1 16]
        self.test_style_b = tf.placeholder(tf.float32, [1, 1, self.style_dim], name='test_style_b')   # [1 1 16]
        
        test_content_a, test_style_a = self.Encoder_A(self.test_domain_A, reuse=True)
        test_content_b, test_style_b = self.Encoder_B(self.test_domain_B, reuse=True)

        self.test_fake_A = self.Decoder_A(content_B=test_content_b, style_A=self.test_style_a, reuse=True)
        self.test_fake_B = self.Decoder_B(content_A=test_content_a, style_B=self.test_style_b, reuse=True)

        self.test_recon_A = self.Decoder_A(content_B=test_content_a, style_A=test_style_a, reuse=True)
        self.test_recon_B = self.Decoder_B(content_A=test_content_b, style_B=test_style_b, reuse=True)
        
        
        """ Guided Speech Translation """
        self.content_audio = tf.placeholder(tf.float32, [1, self.audio_ch, self.audio_len], name='content_audio')
        self.style_audio = tf.placeholder(tf.float32, [1, self.audio_ch, self.audio_len], name='guide_style_audio_ch')

        if self.direction == 'A2B' :
            guide_content_A, guide_style_A = self.Encoder_A(self.content_audio, reuse=True)
            guide_content_B, guide_style_B = self.Encoder_B(self.style_audio, reuse=True)

        else :
            guide_content_B, guide_style_B = self.Encoder_B(self.content_audio, reuse=True)
            guide_content_A, guide_style_A = self.Encoder_A(self.style_audio, reuse=True)

        self.guide_fake_A = self.Decoder_A(content_B=guide_content_B, style_A=guide_style_A, reuse=True)
        self.guide_fake_B = self.Decoder_B(content_A=guide_content_A, style_B=guide_style_B, reuse=True)
    
    
    def data_prepare(self, f0s_A, f0s_B, coded_sps_norm_A, coded_sps_norm_B):
        
        train_data_A = sample_train_data03(sps=list(coded_sps_norm_A), f0s=list(f0s_A), n_frames=self.audio_len)
        train_data_B = sample_train_data03(sps=list(coded_sps_norm_B), f0s=list(f0s_B), n_frames=self.audio_len)

        minlen = min(len(train_data_A), len(train_data_B))
        np.random.shuffle(train_data_A)
        np.random.shuffle(train_data_B)
        train_data_A = np.array(train_data_A[0:minlen])
        train_data_B = np.array(train_data_B[0:minlen])

        return train_data_A, train_data_B
    
    
    def train(self):
        # initialize all variables
        tf.global_variables_initializer().run()
        
        # saver to save model
        self.saver = tf.train.Saver()
        
        # summary writer
        self.writer = tf.summary.FileWriter(self.log_dir + '/' + self.model_dir, self.sess.graph)
        
        # restore check-point if it exits
        could_load, checkpoint_counter = self.load(self.checkpoint_dir)
        if could_load:
            start_epoch = (int)(checkpoint_counter / self.iteration)
            start_batch_id = checkpoint_counter - start_epoch * self.iteration
            counter = checkpoint_counter
            print(" [*] Load SUCCESS")
        else:
            start_epoch = 0
            start_batch_id = 0
            counter = 1
            print(" [!] Load FAILED...")
            
        # check sample_dir    
        check_folder(self.sample_dir)
        
        
        '''Training loop for epoch'''
        
        # load data and extract features
        f0s_A, coded_sps_norm_A, log_f0s_mean_A, log_f0s_std_A, coded_sps_mean_A, coded_sps_std_A = vocoder_extract(self.train_A_dir)
        f0s_B, coded_sps_norm_B, log_f0s_mean_B, log_f0s_std_B, coded_sps_mean_B, coded_sps_std_B = vocoder_extract(self.train_B_dir)
        
        # load validation data
        wavs_val_A = load_wavs(wav_dir=self.validation_A_dir, sr=self.sampling_rate)
        wavs_val_B = load_wavs(wav_dir=self.validation_B_dir, sr=self.sampling_rate)

        start_time = time.time()
        for epoch in range(start_epoch, self.epoch):
            
            train_data_A, train_data_B = self.data_prepare(f0s_A, f0s_B, coded_sps_norm_A, coded_sps_norm_B)
            print('Epoch[%d]: Input data sampled from %d A and %d B audio files: train_data_A' %(epoch, len(f0s_A), len(f0s_B)), np.shape(train_data_A), 'train_data_B', np.shape(train_data_B))

            lr_D, lr_G = self.init_lr_D * pow(0.995, epoch), self.init_lr_G * pow(0.995, epoch)
            for idx in range(start_batch_id, self.iteration):
                style_a = np.random.normal(loc=0.0, scale=1.0, size=[self.batch_size, 1, self.style_dim])
                style_b = np.random.normal(loc=0.0, scale=1.0, size=[self.batch_size, 1, self.style_dim])
                
                idx_A = idx%len(train_data_A)
                idx_B = idx%len(train_data_B)
                domain_A = train_data_A[idx_A:idx_A+1].astype('float32')
                domain_B = train_data_B[idx_B:idx_B+1].astype('float32')
                
                train_feed_dict = {
                    self.style_a : style_a,
                    self.style_b : style_b,
                    self.lr_D : lr_D,
                    self.lr_G : lr_G,
                    self.domain_A : domain_A,
                    self.domain_B : domain_B
                }
                
                # Update D
                _, d_loss, summary_str = self.sess.run([self.D_optim, self.Discriminator_loss, self.D_loss], feed_dict = train_feed_dict)
                self.writer.add_summary(summary_str, counter)
            
                # Update G
                batch_A_audios, batch_B_audios, fake_A, fake_B, _, g_loss, summary_str = \
                self.sess.run([self.real_A, self.real_B, self.fake_A, self.fake_B, self.G_optim, \
                               self.Generator_loss, self.G_loss], feed_dict = train_feed_dict)
                self.writer.add_summary(summary_str, counter)           
            
                # display training status
                counter += 1
                print("Epoch: [%2d] [%6d/%6d] time: %4.4f d_loss: %.8f, g_loss: %.8f" \
                      % (epoch, idx, self.iteration, time.time() - start_time, d_loss, g_loss), end='\r')
            
                # save generated samples
                if np.mod(counter+1, self.sample_freq) == 0:
                    # A2B
                    idx_val_A = (counter//self.sample_freq)%len(wavs_val_A)
                    wav = wavs_val_A[idx_val_A]
                    wav = wav_padding(wav = wav, sr = self.sampling_rate, frame_period = self.frame_period, multiple = 4)
                    # f0 conversion
                    f0, timeaxis, sp, ap = world_decompose(wav = wav, fs = self.sampling_rate, frame_period = self.frame_period)
                    f0_converted = pitch_conversion(f0 = f0, mean_log_src = log_f0s_mean_A, std_log_src = log_f0s_std_A, mean_log_target = log_f0s_mean_B, std_log_target = log_f0s_std_B)
                    # sp normalization
                    coded_sp = world_encode_spectral_envelop(sp = sp, fs = self.sampling_rate, dim = self.num_mcep)
                    coded_sp_transposed = coded_sp.T
                    coded_sp_norm = (coded_sp_transposed - coded_sps_mean_A) / coded_sps_std_A
                    # random sampled style
                    test_style_b = np.random.normal(loc=0.0, scale=1.0, size=[1, 1, self.style_dim])
                    # sp conversion (A2B)
                    coded_sp_converted_norm = self.sess.run(self.test_fake_B, feed_dict = {self.test_domain_A: np.array([coded_sp_norm]), self.test_style_b : test_style_b})
                    coded_sp_converted_norm_recon = self.sess.run(self.test_recon_A, feed_dict = {self.test_domain_A: np.array([coded_sp_norm])})
                    # [1,24,None]
                    # de-normalization
                    coded_sp_converted = coded_sp_converted_norm[0] * coded_sps_std_B + coded_sps_mean_B
                    coded_sp_converted = coded_sp_converted.T
                    coded_sp_converted = np.ascontiguousarray(coded_sp_converted)
                    coded_sp_converted_recon = coded_sp_converted_norm_recon[0] * coded_sps_std_A + coded_sps_mean_A
                    coded_sp_converted_recon = coded_sp_converted_recon.T
                    coded_sp_converted_recon = np.ascontiguousarray(coded_sp_converted_recon)
                    # combine converted f0, sp and ap
                    decoded_sp_converted = world_decode_spectral_envelop(coded_sp = coded_sp_converted, fs = self.sampling_rate)
                    decoded_sp_converted_recon = world_decode_spectral_envelop(coded_sp = coded_sp_converted_recon, fs = self.sampling_rate)                   
                    wav_transformed = world_speech_synthesis(f0 = f0_converted, decoded_sp = decoded_sp_converted, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
                    wav_transformed_recon = world_speech_synthesis(f0 = f0, decoded_sp = decoded_sp_converted_recon, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
                    # write .wav file
                    path_A2B = './{}/fake_A2B_id{:03d}_iter{:03d}K.wav'.format(self.sample_dir, idx_val_A, counter//1000)
                    path_A2A = './{}/recon_A2A_id{:03d}_iter{:03d}K.wav'.format(self.sample_dir, idx_val_A, counter//1000)
                    save_audio(wav=wav_transformed, path=path_A2B, sr=self.sampling_rate)
                    save_audio(wav=wav_transformed_recon, path=path_A2A, sr=self.sampling_rate)
                    
                
                # save checkpoints
                if np.mod(counter+1, self.save_freq) == 0 :
                    self.save(self.checkpoint_dir, counter)
        
            # After an epoch, start_batch_id reset to zero
            # non-zero value is only for the first epoch after loading pre-trained model
            start_batch_id = 0

            # save model for final step
            self.save(self.checkpoint_dir, counter)
            
        print(" [*] Training finished!")
        
    
    def test(self):
        # initialize all variables
        tf.global_variables_initializer().run()
               
        # saver to save model
        self.saver = tf.train.Saver()
    
        # load check-point if it exits
        could_load, checkpoint_counter = self.load(self.checkpoint_dir)
    
        if could_load :
            print(" [*] Load SUCCESS")
        else :
            print(" [!] Load FAILED...")
    
        # check result_dir
        check_folder(self.result_dir)
        
        # write html for visual comparison
        
        
        # Get statistic from train_A, train_B
        _, _, log_f0s_mean_A, log_f0s_std_A, coded_sps_A_mean, coded_sps_A_std = vocoder_extract(self.train_A_dir)
        _, _, log_f0s_mean_B, log_f0s_std_B, coded_sps_B_mean, coded_sps_B_std = vocoder_extract(self.train_B_dir) 
        print('std_log_src:', log_f0s_std_A, 'std_log_target', log_f0s_std_B)
        
        
        # A2B
        test_files_A = os.listdir(self.validation_A_dir)
        for i in range(len(test_files_A)):
            file = test_files_A[i]
            filepath = os.path.join(self.validation_A_dir, file)
            wav, _ = librosa.load(filepath, sr = self.sampling_rate, mono = True)
            wav = wav_padding(wav = wav, sr = self.sampling_rate, frame_period = self.frame_period, multiple = 4)
            f0, timeaxis, sp, ap = world_decompose(wav = wav, fs = self.sampling_rate, frame_period = self.frame_period)
            
            # f0 conversion
            f0_converted = pitch_conversion(f0 = f0, mean_log_src = log_f0s_mean_A, std_log_src = log_f0s_std_A, mean_log_target = log_f0s_mean_B, std_log_target = log_f0s_std_B)

            # sp normalization
            coded_sp = world_encode_spectral_envelop(sp = sp, fs = self.sampling_rate, dim = self.num_mcep)
            coded_sp_transposed = coded_sp.T
            coded_sp_norm = (coded_sp_transposed - coded_sps_A_mean) / coded_sps_A_std
            
            # random sampled style
            test_style_b = np.random.normal(loc=0.0, scale=1.0, size=[1, 1, self.style_dim])
            
            # sp conversion (A2B)
            coded_sp_converted_norm = self.sess.run(self.test_fake_B, feed_dict = {self.test_domain_A: np.array([coded_sp_norm]), self.test_style_b : test_style_b})
            # [1,24,None]
            
            # print('coded_sp_converted_norm', np.shape(coded_sp_converted_norm[0]), 'coded_sps_B_mean', np.shape(coded_sps_B_mean), 'coded_sps_B_std:', np.shape(coded_sps_B_std))          
            coded_sp_converted = coded_sp_converted_norm[0] * coded_sps_B_std + coded_sps_B_mean
            coded_sp_converted = coded_sp_converted.T
            coded_sp_converted = np.ascontiguousarray(coded_sp_converted)
            decoded_sp_converted = world_decode_spectral_envelop(coded_sp = coded_sp_converted, fs = self.sampling_rate)
            wav_transformed = world_speech_synthesis(f0 = f0_converted, decoded_sp = decoded_sp_converted, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
            librosa.output.write_wav(os.path.join(self.result_dir, os.path.basename(file)), wav_transformed, self.sampling_rate)
            
            print('converting test samples: [%d/%d]' %(i+1, len(test_files_A)), end='\r')
            
        print(" [*] Testing finished!")
        
        
        
    @property
    def model_dir(self):
        return "{}_{}_{}".format(self.model_name, self.dataset_name, self.gan_type)
    
    
    def load(self, checkpoint_dir):
        import re
        print(" [*] Reading checkpoints...")
        checkpoint_dir = os.path.join(checkpoint_dir, self.model_dir)

        ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
            self.saver.restore(self.sess, os.path.join(checkpoint_dir, ckpt_name))
            counter = int(next(re.finditer("(\d+)(?!.*\d)", ckpt_name)).group(0))
            print(" [*] Success to read {}".format(ckpt_name))
            return True, counter
        else:
            print(" [*] Failed to find a checkpoint")
            return False, 0
        
        
    def save(self, checkpoint_dir, step):
        checkpoint_dir = os.path.join(checkpoint_dir, self.model_dir)

        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        self.saver.save(self.sess, os.path.join(checkpoint_dir, self.model_name + '.model'), global_step=step)

# %% [markdown]
# ## Train

# %%
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
    model = EmoMUNIT(sess)
    model.build_model()
    model.train()
    model.test()
# Out:
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from checkpoint/EmoMUNIT_ang2neu_lsgan/EmoMUNIT.model-1001
#  [*] Success to read EmoMUNIT.model-1001
#  [*] Load SUCCESS
# std_log_src: 0.385568596071032 std_log_target 0.28322630020087086
#  [*] Testing finished!s: [19/19]

# %% [markdown]
# ## Module: CYCLE

# %%
from utils import *
from ops_c import *

# %%
def generator(inputs, reuse = False, scope_name = 'generator'):

    # inputs has shape [batch_size, num_features, time]
    # we need to convert it to [batch_size, time, num_features] for 1D convolution
    inputs = tf.transpose(inputs, perm = [0, 2, 1], name = 'input_transpose')

    with tf.variable_scope(scope_name) as scope:
        # Discriminator would be reused in CycleGAN
        if reuse:
            scope.reuse_variables()
        else:
            assert scope.reuse is False

        h1 = conv1d_layer(inputs = inputs, filters = 128, kernel_size = 15, strides = 1, activation = None, name = 'h1_conv')
        h1_gates = conv1d_layer(inputs = inputs, filters = 128, kernel_size = 15, strides = 1, activation = None, name = 'h1_conv_gates')
        h1_glu = gated_linear_layer(inputs = h1, gates = h1_gates, name = 'h1_glu')

        # Downsample
        d1 = downsample1d_block(inputs = h1_glu, filters = 256, kernel_size = 5, strides = 2, name_prefix = 'downsample1d_block1_')
        d2 = downsample1d_block(inputs = d1, filters = 512, kernel_size = 5, strides = 2, name_prefix = 'downsample1d_block2_')

        # Residual blocks
        r1 = residual1d_block(inputs = d2, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block1_')
        r2 = residual1d_block(inputs = r1, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block2_')
        r3 = residual1d_block(inputs = r2, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block3_')
        r4 = residual1d_block(inputs = r3, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block4_')
        r5 = residual1d_block(inputs = r4, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block5_')
        r6 = residual1d_block(inputs = r5, filters = 1024, kernel_size = 3, strides = 1, name_prefix = 'residual1d_block6_')

        # Upsample
        u1 = upsample1d_block(inputs = r6, filters = 1024, kernel_size = 5, strides = 1, shuffle_size = 2, name_prefix = 'upsample1d_block1_')
        u2 = upsample1d_block(inputs = u1, filters = 512, kernel_size = 5, strides = 1, shuffle_size = 2, name_prefix = 'upsample1d_block2_')

        # Output
        o1 = conv1d_layer(inputs = u2, filters = 24, kernel_size = 15, strides = 1, activation = None, name = 'o1_conv')
        o2 = tf.transpose(o1, perm = [0, 2, 1], name = 'output_transpose')

    return o2

# %%
def discriminator(inputs, reuse = False, scope_name = 'discriminator'):

    # inputs has shape [batch_size, num_features, time]
    # we need to add channel for 2D convolution [batch_size, num_features, time, 1]
    inputs = tf.expand_dims(inputs, -1)

    with tf.variable_scope(scope_name) as scope:
        # Discriminator would be reused in CycleGAN
        if reuse:
            scope.reuse_variables()
        else:
            assert scope.reuse is False

        h1 = conv2d_layer(inputs = inputs, filters = 128, kernel_size = [3, 3], strides = [1, 2], activation = None, name = 'h1_conv')
        h1_gates = conv2d_layer(inputs = inputs, filters = 128, kernel_size = [3, 3], strides = [1, 2], activation = None, name = 'h1_conv_gates')
        h1_glu = gated_linear_layer(inputs = h1, gates = h1_gates, name = 'h1_glu')

        # Downsample
        d1 = downsample2d_block(inputs = h1_glu, filters = 256, kernel_size = [3, 3], strides = [2, 2], name_prefix = 'downsample2d_block1_')
        d2 = downsample2d_block(inputs = d1, filters = 512, kernel_size = [3, 3], strides = [2, 2], name_prefix = 'downsample2d_block2_')
        d3 = downsample2d_block(inputs = d2, filters = 1024, kernel_size = [6, 3], strides = [1, 2], name_prefix = 'downsample2d_block3_')

        # Output
        o1 = tf.layers.dense(inputs = d3, units = 1, activation = tf.nn.sigmoid)

        return o1

# %%
def discriminator_loss(type, real, fake):
    real = [real]
    fake = [fake]
    
    n_scale = len(real)
    loss = []

    real_loss = 0
    fake_loss = 0

    for i in range(n_scale) :
        if type == 'lsgan' :
            real_loss = tf.reduce_mean(tf.squared_difference(real[i], 1.0))
            fake_loss = tf.reduce_mean(tf.square(fake[i]))

        if type == 'gan' :
            real_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(real[i]), logits=real[i]))
            fake_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.zeros_like(fake[i]), logits=fake[i]))

        loss.append(real_loss + fake_loss)

    return sum(loss)

# %%
def generator_loss(type, fake):
    fake = [fake]
    n_scale = len(fake)
    loss = []

    fake_loss = 0

    for i in range(n_scale) :
        if type == 'lsgan' :
            fake_loss = tf.reduce_mean(tf.squared_difference(fake[i], 1.0))

        if type == 'gan' :
            fake_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(fake[i]), logits=fake[i]))

        loss.append(fake_loss)

    return sum(loss)

# %%
class CYCLE(object):
    def __init__(self, sess, source='neu', target='sad'):
        
        self.train_A_dir = './../../../Database/Emotion/' + source + '_' + target + '/' + source
        self.train_B_dir = './../../../Database/Emotion/' + source + '_' + target + '/' + target
        self.validation_A_dir = './../../../Database/Emotion/' + source + '_' + target + '/' + 'val_' + source
        self.validation_B_dir = './../../../Database/Emotion/' + source + '_' + target + '/' + 'val_' + target
        
        self.discriminator = discriminator
        self.generator = generator
        
        self.batch_size = 1
        self.max_samples = 1000
        
        self.frame_period = 5.0
        self.num_mcep = 24
        self.audio_ch = self.num_mcep
        self.audio_len = 128                              # audio_len == n_frames, time_length
        self.sampling_rate = 16000
        
        self.input_shape = [None, self.audio_ch, None]    # [batch_size, num_features, num_frames]
    
        self.init_lr_G = 0.0002
        self.init_lr_D = 0.0001
        self.lr_G_decay = self.init_lr_G / 200000
        self.lr_D_decay = self.init_lr_D / 200000  
        
        self.cycle_w = 10.0
        self.identity_w = 5.0
        
        
        self.dataset_name = source + '_' + target
        self.model_name = 'C'
        self.gan_type = 'lsgan'
        self.log_dir = "logs/" # + datetime.now().strftime("%Y%m%d-%H%M%S")
        self.sample_dir = 'samples'
        self.checkpoint_dir = 'checkpoint'
        self.A2B_dir = 'results/' + source + '2' + target
        self.B2A_dir = 'results/' + target + '2' + source
        
        self.sample_freq = 1000
        self.save_freq = 1000
        
        self.sess = sess
        self.epoch = 300
        self.iteration = 1000


    def build_model(self):
        # Placeholders for learning rate
        self.lr_D = tf.placeholder(tf.float32, name='learning_rate_D')
        self.lr_G = tf.placeholder(tf.float32, name='learning_rate_G')
        
        # Placeholders for real training samples
        self.x_a = tf.placeholder(tf.float32, shape=self.input_shape, name='real_a')
        self.x_b = tf.placeholder(tf.float32, shape=self.input_shape, name='real_b')
        
        # Placeholder for real test samples
        self.x_a_test = tf.placeholder(tf.float32, shape = self.input_shape, name = 'real_a_test')
        self.x_b_test = tf.placeholder(tf.float32, shape = self.input_shape, name = 'real_b_test')
        
        # Generation
        x_ba = self.generator(inputs = self.x_a, reuse = False, scope_name = 'generator_A2B')
        x_aba = self.generator(inputs = x_ba, reuse = False, scope_name = 'generator_B2A')
        
        x_ab = self.generator(inputs = self.x_b, reuse = True, scope_name = 'generator_B2A')
        x_bab = self.generator(inputs = x_ab, reuse = True, scope_name = 'generator_A2B')        
        
        x_aa = self.generator(inputs = self.x_a, reuse = True, scope_name = 'generator_B2A')
        x_bb = self.generator(inputs = self.x_b, reuse = True, scope_name = 'generator_A2B')
        
        # Discrimination
        fake_A_logit = self.discriminator(inputs = x_ab, reuse = False, scope_name = 'discriminator_A')
        fake_B_logit = self.discriminator(inputs = x_ba, reuse = False, scope_name = 'discriminator_B')
        
        real_A_logit = self.discriminator(inputs = self.x_a, reuse = True, scope_name = 'discriminator_A')
        real_B_logit = self.discriminator(inputs = self.x_b, reuse = True, scope_name = 'discriminator_B')
        
        # Reserved for test
        x_ba_test = self.generator(inputs = self.x_a_test, reuse = True, scope_name = 'generator_A2B')
        x_aba_test = self.generator(inputs = x_ba_test, reuse = True, scope_name = 'generator_B2A')
        
        x_ab_test = self.generator(inputs = self.x_b_test, reuse = True, scope_name = 'generator_B2A')
        x_bab_test = self.generator(inputs = x_ab_test, reuse = True, scope_name = 'generator_A2B')
        
        
        """ Define Loss """
        # Cycle loss
        cycle_loss = l1_loss(y = self.x_a, y_hat = x_aba) + l1_loss(y = self.x_b, y_hat = x_bab)
        
        # Identity loss
        identity_loss = l1_loss(y = self.x_a, y_hat = x_aa) + l1_loss(y = self.x_b, y_hat = x_bb)

        # adversarial Loss
        G_ad_loss_a = l2_loss(y=tf.ones_like(fake_A_logit), y_hat=fake_A_logit)
        G_ad_loss_b = l2_loss(y=tf.ones_like(fake_B_logit), y_hat=fake_B_logit)
#         G_ad_loss_a = generator_loss(self.gan_type, fake_A_logit)
#         G_ad_loss_b = generator_loss(self.gan_type, fake_B_logit)
    
        # Generator loss
        self.Generator_loss = G_ad_loss_a + G_ad_loss_b + self.cycle_w*cycle_loss + self.identity_w*identity_loss
    
    
        # real/fake Loss
        D_loss_A_real = l2_loss(y = tf.ones_like(real_A_logit), y_hat = real_A_logit)
        D_loss_A_fake = l2_loss(y = tf.zeros_like(fake_A_logit), y_hat = fake_A_logit)
        D_ad_loss_a = (D_loss_A_real + D_loss_A_fake) / 2.0
        
        D_loss_B_real = l2_loss(y = tf.ones_like(real_B_logit), y_hat = real_B_logit)
        D_loss_B_fake = l2_loss(y = tf.zeros_like(fake_B_logit), y_hat = fake_B_logit)
        D_ad_loss_b = (D_loss_B_real + D_loss_B_fake) / 2.0
#         D_ad_loss_a = discriminator_loss(self.gan_type, real_A_logit, fake_A_logit)
#         D_ad_loss_b = discriminator_loss(self.gan_type, real_B_logit, fake_B_logit)
        
        # Discrimination Loss 
        self.Discriminator_loss = D_ad_loss_a + D_ad_loss_b
    
    
        """ Training Variables """
        # Categorize variables to optimize D_vars and G_vars separately
        t_vars = tf.trainable_variables()
        G_vars = [var for var in t_vars if 'generator' in var.name]
        D_vars = [var for var in t_vars if 'discriminator' in var.name]

        self.G_optim = tf.train.AdamOptimizer(self.lr_G, beta1=0.5, beta2=0.999).minimize(self.Generator_loss, var_list=G_vars)
        self.D_optim = tf.train.AdamOptimizer(self.lr_D, beta1=0.5, beta2=0.999).minimize(self.Discriminator_loss, var_list=D_vars)
    
    
        """" Summary """
        self.all_G_loss = tf.summary.scalar("Generator_loss", self.Generator_loss)
        self.all_D_loss = tf.summary.scalar("Discriminator_loss", self.Discriminator_loss)
        
        self.Cycle_loss = tf.summary.scalar("Cycle_loss", cycle_loss)
        self.Identity_loss = tf.summary.scalar("Identity_loss", identity_loss)

        self.G_ad_loss_a = tf.summary.scalar("G_ad_loss_a", G_ad_loss_a)
        self.G_ad_loss_b = tf.summary.scalar("G_ad_loss_b", G_ad_loss_b)
        
        self.D_ad_loss_a = tf.summary.scalar("D_ad_loss_a", D_ad_loss_a)
        self.D_ad_loss_b = tf.summary.scalar("D_ad_loss_b", D_ad_loss_b)

        self.G_loss = tf.summary.merge([self.G_ad_loss_a, self.G_ad_loss_b, self.Cycle_loss, self.Identity_loss, self.all_G_loss])
        self.D_loss = tf.summary.merge([self.D_ad_loss_a, self.D_ad_loss_b, self.all_D_loss])
    
    
        """ Speech: real and fake """
        self.real_A = self.x_a
        self.real_B = self.x_b

        self.fake_A = x_ab
        self.fake_B = x_ba
        
        self.test_fake_A = x_ab_test
        self.test_fake_B = x_ba_test
        
        self.test_cycle_A = x_aba_test
        self.test_cycle_B = x_bab_test
    
    
    def data_prepare(self, f0s_A, f0s_B, coded_sps_norm_A, coded_sps_norm_B):
        
        train_data_A = sample_train_data03(sps=list(coded_sps_norm_A), f0s=list(f0s_A), n_frames=self.audio_len)
        train_data_B = sample_train_data03(sps=list(coded_sps_norm_B), f0s=list(f0s_B), n_frames=self.audio_len)

        minlen = min(len(train_data_A), len(train_data_B))
        np.random.shuffle(train_data_A)
        np.random.shuffle(train_data_B)
        train_data_A = np.array(train_data_A[0:minlen])
        train_data_B = np.array(train_data_B[0:minlen])

        return train_data_A, train_data_B
    
    
    def train(self):
        # initialize all variables
        tf.global_variables_initializer().run()
        
        # saver to save model
        self.saver = tf.train.Saver()
        
        # summary writer
        self.writer = tf.summary.FileWriter(self.log_dir + '/' + self.model_dir, self.sess.graph)
        
        # restore check-point if it exits
        could_load, checkpoint_counter = self.load(self.checkpoint_dir)
        if could_load:
            start_epoch = (int)(checkpoint_counter / self.iteration)
            start_batch_id = checkpoint_counter - start_epoch * self.iteration
            counter = checkpoint_counter
            print(" [*] Load SUCCESS")
        else:
            start_epoch = 0
            start_batch_id = 0
            counter = 1
            print(" [!] Load FAILED...")
            
        # check sample_dir    
        check_folder(self.sample_dir)
        
        
        '''Training loop for epoch'''
        
        # load data and extract features
        f0s_A, coded_sps_norm_A, log_f0s_mean_A, log_f0s_std_A, coded_sps_mean_A, coded_sps_std_A = vocoder_extract(self.train_A_dir)
        f0s_B, coded_sps_norm_B, log_f0s_mean_B, log_f0s_std_B, coded_sps_mean_B, coded_sps_std_B = vocoder_extract(self.train_B_dir)
        
        # load validation data
        wavs_val_A = load_wavs(wav_dir=self.validation_A_dir, sr=self.sampling_rate)
        wavs_val_B = load_wavs(wav_dir=self.validation_B_dir, sr=self.sampling_rate)

        start_time = time.time()
        for epoch in range(start_epoch, self.epoch):
            
            train_data_A, train_data_B = self.data_prepare(f0s_A, f0s_B, coded_sps_norm_A, coded_sps_norm_B)
            print('Epoch[%d]: Input data sampled from %d A and %d B audio files: train_data_A' %(epoch, len(f0s_A), len(f0s_B)), np.shape(train_data_A), 'train_data_B', np.shape(train_data_B))

            lr_D = self.init_lr_D
            lr_G = self.init_lr_G
            if counter > 20000:
                self.identity_w = 0.0                            # deactivate identity loss
            if counter > 150000:
                lr_G = max(0.0, self.init_lr_G - self.lr_G_decay)
                lr_D = max(0.0, self.init_lr_D - self.lr_D_decay)
#             lr_D = self.init_lr_D * pow(0.995, epoch)
#             lr_G = self.init_lr_G * pow(0.995, epoch)

            if counter < 50000:
                G_iter = 2
            elif 50000 <= counter < 100000:
                G_iter = np.random.randint(2) + 1
            else:
                G_iter = 1

#             n_iter = len(train_data_A)
            n_iter = self.iteration
        
            for idx in range(start_batch_id, n_iter):

                idx_A = idx%len(train_data_A)
                idx_B = idx%len(train_data_B)
                domain_A = train_data_A[idx_A:idx_A+1].astype('float32')
                domain_B = train_data_B[idx_B:idx_B+1].astype('float32')
                
                train_feed_dict = {
                    self.lr_D : lr_D,
                    self.lr_G : lr_G,
                    self.x_a : domain_A,
                    self.x_b : domain_B
                }
                
                # Update D
                if counter % G_iter == G_iter - 1:
                    _, d_loss, summary_str = self.sess.run([self.D_optim, self.Discriminator_loss, self.D_loss], feed_dict = train_feed_dict)
                    self.writer.add_summary(summary_str, counter)
            
                # Update G
                batch_A_audios, batch_B_audios, fake_A, fake_B, _, g_loss, summary_str = \
                self.sess.run([self.real_A, self.real_B, self.fake_A, self.fake_B, self.G_optim, \
                               self.Generator_loss, self.G_loss], feed_dict = train_feed_dict)
                self.writer.add_summary(summary_str, counter)
            
            
                ''' Display Training Status '''
                counter += 1
                print("Epoch: [%2d] [%6d/%6d] time: %4.4f d_loss: %.8f, g_loss: %.8f" \
                      % (epoch, idx, n_iter, time.time() - start_time, d_loss, g_loss), end='\r')
            
                # save generated samples
                if np.mod(counter+1, self.sample_freq) == 0:
                    # A2B
                    idx_val_A = (counter//self.sample_freq)%len(wavs_val_A)
                    wav = wavs_val_A[idx_val_A]
                    wav = wav_padding(wav = wav, sr = self.sampling_rate, frame_period = self.frame_period, multiple = 4)
                    
                    # f0 conversion
                    f0, timeaxis, sp, ap = world_decompose(wav = wav, fs = self.sampling_rate, frame_period = self.frame_period)
                    f0_converted = pitch_conversion(f0 = f0, mean_log_src = log_f0s_mean_A, std_log_src = log_f0s_std_A, mean_log_target = log_f0s_mean_B, std_log_target = log_f0s_std_B)
                    
                    # sp normalization
                    coded_sp = world_encode_spectral_envelop(sp = sp, fs = self.sampling_rate, dim = self.num_mcep)
                    coded_sp_transposed = coded_sp.T
                    coded_sp_norm = (coded_sp_transposed - coded_sps_mean_A) / coded_sps_std_A

                    # sp conversion (A2B)
                    coded_sp_converted_norm = self.sess.run(self.test_fake_B, feed_dict = {self.x_a_test: np.array([coded_sp_norm])})
                    coded_sp_converted_norm_cycle = self.sess.run(self.test_cycle_A, feed_dict = {self.x_a_test: np.array([coded_sp_norm])})
                    # [1,24,None]
                    
                    # de-normalization
                    coded_sp_converted = coded_sp_converted_norm[0] * coded_sps_std_B + coded_sps_mean_B
                    coded_sp_converted = coded_sp_converted.T
                    coded_sp_converted = np.ascontiguousarray(coded_sp_converted)
                    coded_sp_converted_cycle = coded_sp_converted_norm_cycle[0] * coded_sps_std_A + coded_sps_mean_A
                    coded_sp_converted_cycle = coded_sp_converted_cycle.T
                    coded_sp_converted_cycle = np.ascontiguousarray(coded_sp_converted_cycle)
                    
                    # combine converted f0, sp and ap
                    decoded_sp_converted = world_decode_spectral_envelop(coded_sp = coded_sp_converted, fs = self.sampling_rate)
                    decoded_sp_converted_cycle = world_decode_spectral_envelop(coded_sp = coded_sp_converted_cycle, fs = self.sampling_rate)                   
                    wav_transformed = world_speech_synthesis(f0 = f0_converted, decoded_sp = decoded_sp_converted, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
                    wav_transformed_cycle = world_speech_synthesis(f0 = f0, decoded_sp = decoded_sp_converted_cycle, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
                    
                    # write .wav file
                    path_A2B = './{}/fake_A2B_id{:03d}_iter{:03d}K.wav'.format(self.sample_dir, idx_val_A, counter//1000)
                    path_A2A = './{}/cycle_A2A_id{:03d}_iter{:03d}K.wav'.format(self.sample_dir, idx_val_A, counter//1000)
                    save_audio(wav=wav_transformed, path=path_A2B, sr=self.sampling_rate)
                    save_audio(wav=wav_transformed_cycle, path=path_A2A, sr=self.sampling_rate)
                    
                
                # save checkpoints
                if np.mod(counter+1, self.save_freq) == 0 :
                    self.save(self.checkpoint_dir, counter)
        
            # After an epoch, start_batch_id reset to zero
            # non-zero value is only for the first epoch after loading pre-trained model
            start_batch_id = 0

            # save model for final step
            self.save(self.checkpoint_dir, counter)
            
        print(" [*] Training finished!")
        
    
    def test(self):
        # initialize all variables
        tf.global_variables_initializer().run()
               
        # saver to save model
        self.saver = tf.train.Saver()
    
        # load check-point if it exits
        could_load, checkpoint_counter = self.load(self.checkpoint_dir)
    
        if could_load :
            print(" [*] Load SUCCESS")
        else :
            print(" [!] Load FAILED...")
    
        # check result_dir
        check_folder(self.A2B_dir)
        check_folder(self.B2A_dir)
        
        # Get statistic from train_A, train_B
        _, _, log_f0s_mean_A, log_f0s_std_A, coded_sps_A_mean, coded_sps_A_std = vocoder_extract(self.train_A_dir)
        _, _, log_f0s_mean_B, log_f0s_std_B, coded_sps_B_mean, coded_sps_B_std = vocoder_extract(self.train_B_dir) 
        print('std_log_src:', log_f0s_std_A, 'std_log_target', log_f0s_std_B)
        
        
        # A2B
        test_files_A = os.listdir(self.validation_A_dir)
        for i in range(len(test_files_A)):
            file = test_files_A[i]
            filepath = os.path.join(self.validation_A_dir, file)
            wav, _ = librosa.load(filepath, sr = self.sampling_rate, mono = True)
            wav = wav_padding(wav = wav, sr = self.sampling_rate, frame_period = self.frame_period, multiple = 4)
            f0, timeaxis, sp, ap = world_decompose(wav = wav, fs = self.sampling_rate, frame_period = self.frame_period)
            
            # f0 conversion
            f0_converted = pitch_conversion(f0 = f0, mean_log_src = log_f0s_mean_A, std_log_src = log_f0s_std_A, mean_log_target = log_f0s_mean_B, std_log_target = log_f0s_std_B)

            # sp normalization
            coded_sp = world_encode_spectral_envelop(sp = sp, fs = self.sampling_rate, dim = self.num_mcep)
            coded_sp_transposed = coded_sp.T
            coded_sp_norm = (coded_sp_transposed - coded_sps_A_mean) / coded_sps_A_std
            
            # sp conversion (A2B)
            coded_sp_converted_norm = self.sess.run(self.test_fake_B, feed_dict = {self.x_a_test: np.array([coded_sp_norm])})
            # [1,24,None]
            
            # print('coded_sp_converted_norm', np.shape(coded_sp_converted_norm[0]), 'coded_sps_B_mean', np.shape(coded_sps_B_mean), 'coded_sps_B_std:', np.shape(coded_sps_B_std))          
            coded_sp_converted = coded_sp_converted_norm[0] * coded_sps_B_std + coded_sps_B_mean
            coded_sp_converted = coded_sp_converted.T
            coded_sp_converted = np.ascontiguousarray(coded_sp_converted)
            decoded_sp_converted = world_decode_spectral_envelop(coded_sp = coded_sp_converted, fs = self.sampling_rate)
            wav_transformed = world_speech_synthesis(f0 = f0_converted, decoded_sp = decoded_sp_converted, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
            librosa.output.write_wav(os.path.join(self.A2B_dir, os.path.basename(file)), wav_transformed, self.sampling_rate)
            
            print('converting test samples A2B: [%d/%d]' %(i+1, len(test_files_A)), end='\r')
        
        # B2A
        test_files_B = os.listdir(self.validation_B_dir)
        for i in range(len(test_files_B)):
            file = test_files_B[i]
            filepath = os.path.join(self.validation_B_dir, file)
            wav, _ = librosa.load(filepath, sr = self.sampling_rate, mono = True)
            wav = wav_padding(wav = wav, sr = self.sampling_rate, frame_period = self.frame_period, multiple = 4)
            f0, timeaxis, sp, ap = world_decompose(wav = wav, fs = self.sampling_rate, frame_period = self.frame_period)
            
            # f0 conversion
            f0_converted = pitch_conversion(f0 = f0, mean_log_src = log_f0s_mean_B, std_log_src = log_f0s_std_B, mean_log_target = log_f0s_mean_A, std_log_target = log_f0s_std_A)

            # sp normalization
            coded_sp = world_encode_spectral_envelop(sp = sp, fs = self.sampling_rate, dim = self.num_mcep)
            coded_sp_transposed = coded_sp.T
            coded_sp_norm = (coded_sp_transposed - coded_sps_B_mean) / coded_sps_B_std
            
            # sp conversion (A2B)
            coded_sp_converted_norm = self.sess.run(self.test_fake_A, feed_dict = {self.x_b_test: np.array([coded_sp_norm])})
            # [1,24,None]
            
            # print('coded_sp_converted_norm', np.shape(coded_sp_converted_norm[0]), 'coded_sps_A_mean', np.shape(coded_sps_A_mean), 'coded_sps_A_std:', np.shape(coded_sps_A_std))          
            coded_sp_converted = coded_sp_converted_norm[0] * coded_sps_A_std + coded_sps_A_mean
            coded_sp_converted = coded_sp_converted.T
            coded_sp_converted = np.ascontiguousarray(coded_sp_converted)
            decoded_sp_converted = world_decode_spectral_envelop(coded_sp = coded_sp_converted, fs = self.sampling_rate)
            wav_transformed = world_speech_synthesis(f0 = f0_converted, decoded_sp = decoded_sp_converted, ap = ap, fs = self.sampling_rate, frame_period = self.frame_period)
            librosa.output.write_wav(os.path.join(self.B2A_dir, os.path.basename(file)), wav_transformed, self.sampling_rate)
            
            print('converting test samples B2A: [%d/%d]' %(i+1, len(test_files_B)), end='\r')
        
        
        print(" [*] Testing finished!")
        
        
        
    @property
    def model_dir(self):
        return "{}_{}_{}".format(self.model_name, self.dataset_name, self.gan_type)
    
    
    def load(self, checkpoint_dir):
        import re
        print(" [*] Reading checkpoints...")
        checkpoint_dir = os.path.join(checkpoint_dir, self.model_dir)

        ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
            self.saver.restore(self.sess, os.path.join(checkpoint_dir, ckpt_name))
            counter = int(next(re.finditer("(\d+)(?!.*\d)", ckpt_name)).group(0))
            print(" [*] Success to read {}".format(ckpt_name))
            return True, counter
        else:
            print(" [*] Failed to find a checkpoint")
            return False, 0
        
        
    def save(self, checkpoint_dir, step):
        checkpoint_dir = os.path.join(checkpoint_dir, self.model_dir)

        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        self.saver.save(self.sess, os.path.join(checkpoint_dir, self.model_name + '.model'), global_step=step)

# %% [markdown]
# ### Train

# %%
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
    model = CYCLE(sess, source='neu', target='sad')
    model.build_model()
    model.train()
    model.test()
# Out:
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from checkpoint/CYCLE_neu_sad_lsgan/CYCLE.model-82001
#  [*] Success to read CYCLE.model-82001
#  [*] Load SUCCESS
# Epoch[82]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter082K.wav shape: (141760,)s: 8.14507484
# saved file at ./samples/cycle_A2A_id039_iter082K.wav shape: (141760,)
# Epoch[83]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter083K.wav shape: (54400,)ss: 7.37733126
# saved file at ./samples/cycle_A2A_id040_iter083K.wav shape: (54400,)
# Epoch[84]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter084K.wav shape: (37120,)ss: 6.576529984
# saved file at ./samples/cycle_A2A_id041_iter084K.wav shape: (37120,)
# Epoch[85]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id042_iter085K.wav shape: (39360,)oss: 6.28122282
# saved file at ./samples/cycle_A2A_id042_iter085K.wav shape: (39360,)
# Epoch[86]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id000_iter086K.wav shape: (67520,)oss: 6.45837402
# saved file at ./samples/cycle_A2A_id000_iter086K.wav shape: (67520,)
# Epoch[87]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id001_iter087K.wav shape: (41920,)oss: 6.818253993
# saved file at ./samples/cycle_A2A_id001_iter087K.wav shape: (41920,)
# Epoch[88]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id002_iter088K.wav shape: (50560,)oss: 6.971722601
# saved file at ./samples/cycle_A2A_id002_iter088K.wav shape: (50560,)
# Epoch[89]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id003_iter089K.wav shape: (37440,)oss: 7.31634474
# saved file at ./samples/cycle_A2A_id003_iter089K.wav shape: (37440,)
# Epoch[90]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id004_iter090K.wav shape: (35840,)oss: 6.46989298
# saved file at ./samples/cycle_A2A_id004_iter090K.wav shape: (35840,)
# Epoch[91]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id005_iter091K.wav shape: (30720,)oss: 6.986978534
# saved file at ./samples/cycle_A2A_id005_iter091K.wav shape: (30720,)
# Epoch[92]: Input data sampled from 128 A and 64 B audio files: train_data_A (382, 24, 128) train_data_B (382, 24, 128)
# saved file at ./samples/fake_A2B_id006_iter092K.wav shape: (64000,)oss: 7.61812019
# saved file at ./samples/cycle_A2A_id006_iter092K.wav shape: (64000,)
# Epoch[93]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id007_iter093K.wav shape: (70400,)oss: 6.93625355
# saved file at ./samples/cycle_A2A_id007_iter093K.wav shape: (70400,)
# Epoch[94]: Input data sampled from 128 A and 64 B audio files: train_data_A (384, 24, 128) train_data_B (384, 24, 128)
# saved file at ./samples/fake_A2B_id008_iter094K.wav shape: (25280,)oss: 7.40423775
# saved file at ./samples/cycle_A2A_id008_iter094K.wav shape: (25280,)
# Epoch[95]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id009_iter095K.wav shape: (22400,)oss: 6.85954189
# saved file at ./samples/cycle_A2A_id009_iter095K.wav shape: (22400,)
# Epoch[96]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id010_iter096K.wav shape: (47680,)oss: 6.79573011
# saved file at ./samples/cycle_A2A_id010_iter096K.wav shape: (47680,)
# Epoch[97]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id011_iter097K.wav shape: (22400,)oss: 7.01463366
# saved file at ./samples/cycle_A2A_id011_iter097K.wav shape: (22400,)
# Epoch[98]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id012_iter098K.wav shape: (19840,)oss: 6.79982138
# saved file at ./samples/cycle_A2A_id012_iter098K.wav shape: (19840,)
# Epoch[99]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id013_iter099K.wav shape: (29760,)oss: 7.396573077
# saved file at ./samples/cycle_A2A_id013_iter099K.wav shape: (29760,)
# Epoch[100]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id014_iter100K.wav shape: (39680,)loss: 5.93373489
# saved file at ./samples/cycle_A2A_id014_iter100K.wav shape: (39680,)
# Epoch[101]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id015_iter101K.wav shape: (38080,)loss: 6.75435257
# saved file at ./samples/cycle_A2A_id015_iter101K.wav shape: (38080,)
# Epoch[102]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id016_iter102K.wav shape: (49280,)loss: 6.88502789
# saved file at ./samples/cycle_A2A_id016_iter102K.wav shape: (49280,)
# Epoch[103]: Input data sampled from 128 A and 64 B audio files: train_data_A (366, 24, 128) train_data_B (366, 24, 128)
# saved file at ./samples/fake_A2B_id017_iter103K.wav shape: (32640,)loss: 6.98349667
# saved file at ./samples/cycle_A2A_id017_iter103K.wav shape: (32640,)
# Epoch[104]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id018_iter104K.wav shape: (31680,)loss: 6.94096994
# saved file at ./samples/cycle_A2A_id018_iter104K.wav shape: (31680,)
# Epoch[105]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id019_iter105K.wav shape: (32320,)loss: 6.23799753
# saved file at ./samples/cycle_A2A_id019_iter105K.wav shape: (32320,)
# Epoch[106]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id020_iter106K.wav shape: (45120,)loss: 6.39960384
# saved file at ./samples/cycle_A2A_id020_iter106K.wav shape: (45120,)
# Epoch[107]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id021_iter107K.wav shape: (30080,)loss: 6.67146158
# saved file at ./samples/cycle_A2A_id021_iter107K.wav shape: (30080,)
# Epoch[108]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id022_iter108K.wav shape: (48000,)loss: 6.94752693
# saved file at ./samples/cycle_A2A_id022_iter108K.wav shape: (48000,)
# Epoch[109]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id023_iter109K.wav shape: (34240,)loss: 6.69033575
# saved file at ./samples/cycle_A2A_id023_iter109K.wav shape: (34240,)
# Epoch[110]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id024_iter110K.wav shape: (57920,)loss: 6.81369400
# saved file at ./samples/cycle_A2A_id024_iter110K.wav shape: (57920,)
# Epoch[111]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id025_iter111K.wav shape: (15360,)loss: 6.92031574
# saved file at ./samples/cycle_A2A_id025_iter111K.wav shape: (15360,)
# Epoch[112]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id026_iter112K.wav shape: (23360,)loss: 7.00781918
# saved file at ./samples/cycle_A2A_id026_iter112K.wav shape: (23360,)
# Epoch[113]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id027_iter113K.wav shape: (59840,)loss: 6.30440092
# saved file at ./samples/cycle_A2A_id027_iter113K.wav shape: (59840,)
# Epoch[114]: Input data sampled from 128 A and 64 B audio files: train_data_A (382, 24, 128) train_data_B (382, 24, 128)
# saved file at ./samples/fake_A2B_id028_iter114K.wav shape: (66240,)loss: 6.22010422
# saved file at ./samples/cycle_A2A_id028_iter114K.wav shape: (66240,)
# Epoch[115]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id029_iter115K.wav shape: (58560,)_loss: 6.61001110
# saved file at ./samples/cycle_A2A_id029_iter115K.wav shape: (58560,)
# Epoch[116]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id030_iter116K.wav shape: (64000,)_loss: 6.23501492
# saved file at ./samples/cycle_A2A_id030_iter116K.wav shape: (64000,)
# Epoch[117]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id031_iter117K.wav shape: (58880,)_loss: 6.94119167
# saved file at ./samples/cycle_A2A_id031_iter117K.wav shape: (58880,)
# Epoch[118]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id032_iter118K.wav shape: (87680,)_loss: 6.442701343
# saved file at ./samples/cycle_A2A_id032_iter118K.wav shape: (87680,)
# Epoch[119]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id033_iter119K.wav shape: (60160,)_loss: 6.26593876
# saved file at ./samples/cycle_A2A_id033_iter119K.wav shape: (60160,)
# Epoch[120]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id034_iter120K.wav shape: (74560,)_loss: 6.78789043
# saved file at ./samples/cycle_A2A_id034_iter120K.wav shape: (74560,)
# Epoch[121]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id035_iter121K.wav shape: (54400,)_loss: 6.33127022
# saved file at ./samples/cycle_A2A_id035_iter121K.wav shape: (54400,)
# Epoch[122]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id036_iter122K.wav shape: (21120,)_loss: 6.10155821
# saved file at ./samples/cycle_A2A_id036_iter122K.wav shape: (21120,)
# Epoch[123]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id037_iter123K.wav shape: (28480,)_loss: 6.64366674
# saved file at ./samples/cycle_A2A_id037_iter123K.wav shape: (28480,)
# Epoch[124]: Input data sampled from 128 A and 64 B audio files: train_data_A (386, 24, 128) train_data_B (386, 24, 128)
# saved file at ./samples/fake_A2B_id038_iter124K.wav shape: (37760,)_loss: 6.33153248
# saved file at ./samples/cycle_A2A_id038_iter124K.wav shape: (37760,)
# Epoch[125]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter125K.wav shape: (141760,)loss: 6.17242622
# saved file at ./samples/cycle_A2A_id039_iter125K.wav shape: (141760,)
# Epoch[126]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter126K.wav shape: (54400,)_loss: 6.13418341
# saved file at ./samples/cycle_A2A_id040_iter126K.wav shape: (54400,)
# Epoch[127]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter127K.wav shape: (37120,)_loss: 6.02935314
# saved file at ./samples/cycle_A2A_id041_iter127K.wav shape: (37120,)
# Epoch[128]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id042_iter128K.wav shape: (39360,)_loss: 5.68544102
# saved file at ./samples/cycle_A2A_id042_iter128K.wav shape: (39360,)
# Epoch[129]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id000_iter129K.wav shape: (67520,)_loss: 5.42429161
# saved file at ./samples/cycle_A2A_id000_iter129K.wav shape: (67520,)
# Epoch[130]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id001_iter130K.wav shape: (41920,)_loss: 5.92626953
# saved file at ./samples/cycle_A2A_id001_iter130K.wav shape: (41920,)
# Epoch[131]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id002_iter131K.wav shape: (50560,)_loss: 6.11986828
# saved file at ./samples/cycle_A2A_id002_iter131K.wav shape: (50560,)
# Epoch[132]: Input data sampled from 128 A and 64 B audio files: train_data_A (370, 24, 128) train_data_B (370, 24, 128)
# saved file at ./samples/fake_A2B_id003_iter132K.wav shape: (37440,)_loss: 6.08819342
# saved file at ./samples/cycle_A2A_id003_iter132K.wav shape: (37440,)
# Epoch[133]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id004_iter133K.wav shape: (35840,)_loss: 5.57586098
# saved file at ./samples/cycle_A2A_id004_iter133K.wav shape: (35840,)
# Epoch[134]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id005_iter134K.wav shape: (30720,)_loss: 5.73356962
# saved file at ./samples/cycle_A2A_id005_iter134K.wav shape: (30720,)
# Epoch[135]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id006_iter135K.wav shape: (64000,)_loss: 5.73596668
# saved file at ./samples/cycle_A2A_id006_iter135K.wav shape: (64000,)
# Epoch[136]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id007_iter136K.wav shape: (70400,)_loss: 6.70990372
# saved file at ./samples/cycle_A2A_id007_iter136K.wav shape: (70400,)
# Epoch[137]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id008_iter137K.wav shape: (25280,)_loss: 6.13146496
# saved file at ./samples/cycle_A2A_id008_iter137K.wav shape: (25280,)
# Epoch[138]: Input data sampled from 128 A and 64 B audio files: train_data_A (385, 24, 128) train_data_B (385, 24, 128)
# saved file at ./samples/fake_A2B_id009_iter138K.wav shape: (22400,)_loss: 5.61411190
# saved file at ./samples/cycle_A2A_id009_iter138K.wav shape: (22400,)
# Epoch[139]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id010_iter139K.wav shape: (47680,)_loss: 6.33613443
# saved file at ./samples/cycle_A2A_id010_iter139K.wav shape: (47680,)
# Epoch[140]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id011_iter140K.wav shape: (22400,)_loss: 5.90058613
# saved file at ./samples/cycle_A2A_id011_iter140K.wav shape: (22400,)
# Epoch[141]: Input data sampled from 128 A and 64 B audio files: train_data_A (366, 24, 128) train_data_B (366, 24, 128)
# saved file at ./samples/fake_A2B_id012_iter141K.wav shape: (19840,)_loss: 5.61821699
# saved file at ./samples/cycle_A2A_id012_iter141K.wav shape: (19840,)
# Epoch[142]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id013_iter142K.wav shape: (29760,)_loss: 6.22660351
# saved file at ./samples/cycle_A2A_id013_iter142K.wav shape: (29760,)
# Epoch[143]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id014_iter143K.wav shape: (39680,)_loss: 5.94516325
# saved file at ./samples/cycle_A2A_id014_iter143K.wav shape: (39680,)
# Epoch[144]: Input data sampled from 128 A and 64 B audio files: train_data_A (383, 24, 128) train_data_B (383, 24, 128)
# saved file at ./samples/fake_A2B_id015_iter144K.wav shape: (38080,)_loss: 5.83430958
# saved file at ./samples/cycle_A2A_id015_iter144K.wav shape: (38080,)
# Epoch[145]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id016_iter145K.wav shape: (49280,)_loss: 5.37100697
# saved file at ./samples/cycle_A2A_id016_iter145K.wav shape: (49280,)
# Epoch[146]: Input data sampled from 128 A and 64 B audio files: train_data_A (382, 24, 128) train_data_B (382, 24, 128)
# saved file at ./samples/fake_A2B_id017_iter146K.wav shape: (32640,)_loss: 6.25040579
# saved file at ./samples/cycle_A2A_id017_iter146K.wav shape: (32640,)
# Epoch[147]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id018_iter147K.wav shape: (31680,)_loss: 6.22814751
# saved file at ./samples/cycle_A2A_id018_iter147K.wav shape: (31680,)
# Epoch[148]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id019_iter148K.wav shape: (32320,)_loss: 5.80568981
# saved file at ./samples/cycle_A2A_id019_iter148K.wav shape: (32320,)
# Epoch[149]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id020_iter149K.wav shape: (45120,)_loss: 5.97681856
# saved file at ./samples/cycle_A2A_id020_iter149K.wav shape: (45120,)
# Epoch[150]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id021_iter150K.wav shape: (30080,)_loss: 6.05503130
# saved file at ./samples/cycle_A2A_id021_iter150K.wav shape: (30080,)
# Epoch[151]: Input data sampled from 128 A and 64 B audio files: train_data_A (370, 24, 128) train_data_B (370, 24, 128)
# saved file at ./samples/fake_A2B_id022_iter151K.wav shape: (48000,)_loss: 5.02879620
# saved file at ./samples/cycle_A2A_id022_iter151K.wav shape: (48000,)
# Epoch[152]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id023_iter152K.wav shape: (34240,)_loss: 5.48117828
# saved file at ./samples/cycle_A2A_id023_iter152K.wav shape: (34240,)
# Epoch[153]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id024_iter153K.wav shape: (57920,)_loss: 6.42381239
# saved file at ./samples/cycle_A2A_id024_iter153K.wav shape: (57920,)
# Epoch[154]: Input data sampled from 128 A and 64 B audio files: train_data_A (365, 24, 128) train_data_B (365, 24, 128)
# saved file at ./samples/fake_A2B_id025_iter154K.wav shape: (15360,)_loss: 5.66049814
# saved file at ./samples/cycle_A2A_id025_iter154K.wav shape: (15360,)
# Epoch[155]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id026_iter155K.wav shape: (23360,)_loss: 6.26804638
# saved file at ./samples/cycle_A2A_id026_iter155K.wav shape: (23360,)
# Epoch[156]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id027_iter156K.wav shape: (59840,)_loss: 7.23866367
# saved file at ./samples/cycle_A2A_id027_iter156K.wav shape: (59840,)
# Epoch[157]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id028_iter157K.wav shape: (66240,)_loss: 4.99888754
# saved file at ./samples/cycle_A2A_id028_iter157K.wav shape: (66240,)
# Epoch[158]: Input data sampled from 128 A and 64 B audio files: train_data_A (382, 24, 128) train_data_B (382, 24, 128)
# saved file at ./samples/fake_A2B_id029_iter158K.wav shape: (58560,)_loss: 5.90211773
# saved file at ./samples/cycle_A2A_id029_iter158K.wav shape: (58560,)
# Epoch[159]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id030_iter159K.wav shape: (64000,)_loss: 5.50148773
# saved file at ./samples/cycle_A2A_id030_iter159K.wav shape: (64000,)
# Epoch[160]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id031_iter160K.wav shape: (58880,)_loss: 5.15939379
# saved file at ./samples/cycle_A2A_id031_iter160K.wav shape: (58880,)
# Epoch[161]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id032_iter161K.wav shape: (87680,)_loss: 5.79819679
# saved file at ./samples/cycle_A2A_id032_iter161K.wav shape: (87680,)
# Epoch[162]: Input data sampled from 128 A and 64 B audio files: train_data_A (370, 24, 128) train_data_B (370, 24, 128)
# saved file at ./samples/fake_A2B_id033_iter162K.wav shape: (60160,)_loss: 5.53520775
# saved file at ./samples/cycle_A2A_id033_iter162K.wav shape: (60160,)
# Epoch[163]: Input data sampled from 128 A and 64 B audio files: train_data_A (386, 24, 128) train_data_B (386, 24, 128)
# saved file at ./samples/fake_A2B_id034_iter163K.wav shape: (74560,)_loss: 5.30686045
# saved file at ./samples/cycle_A2A_id034_iter163K.wav shape: (74560,)
# Epoch[164]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id035_iter164K.wav shape: (54400,)_loss: 6.30122042
# saved file at ./samples/cycle_A2A_id035_iter164K.wav shape: (54400,)
# Epoch[165]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id036_iter165K.wav shape: (21120,)_loss: 5.89454889
# saved file at ./samples/cycle_A2A_id036_iter165K.wav shape: (21120,)
# Epoch[166]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id037_iter166K.wav shape: (28480,)_loss: 5.42798424
# saved file at ./samples/cycle_A2A_id037_iter166K.wav shape: (28480,)
# Epoch[167]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id038_iter167K.wav shape: (37760,)_loss: 5.73762941
# saved file at ./samples/cycle_A2A_id038_iter167K.wav shape: (37760,)
# Epoch[168]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter168K.wav shape: (141760,)loss: 5.39927673
# saved file at ./samples/cycle_A2A_id039_iter168K.wav shape: (141760,)
# Epoch[169]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter169K.wav shape: (54400,)_loss: 6.07936144
# saved file at ./samples/cycle_A2A_id040_iter169K.wav shape: (54400,)
# Epoch[170]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter170K.wav shape: (37120,)_loss: 5.75694609
# saved file at ./samples/cycle_A2A_id041_iter170K.wav shape: (37120,)
# Epoch[171]: Input data sampled from 128 A and 64 B audio files: train_data_A (366, 24, 128) train_data_B (366, 24, 128)
# saved file at ./samples/fake_A2B_id042_iter171K.wav shape: (39360,)_loss: 5.64531994
# saved file at ./samples/cycle_A2A_id042_iter171K.wav shape: (39360,)
# Epoch[172]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id000_iter172K.wav shape: (67520,)_loss: 5.27866650
# saved file at ./samples/cycle_A2A_id000_iter172K.wav shape: (67520,)
# Epoch[173]: Input data sampled from 128 A and 64 B audio files: train_data_A (363, 24, 128) train_data_B (363, 24, 128)
# saved file at ./samples/fake_A2B_id001_iter173K.wav shape: (41920,)_loss: 5.71461964
# saved file at ./samples/cycle_A2A_id001_iter173K.wav shape: (41920,)
# Epoch[174]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id002_iter174K.wav shape: (50560,)_loss: 5.57584190
# saved file at ./samples/cycle_A2A_id002_iter174K.wav shape: (50560,)
# Epoch[175]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id003_iter175K.wav shape: (37440,)_loss: 5.35919762
# saved file at ./samples/cycle_A2A_id003_iter175K.wav shape: (37440,)
# Epoch[176]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id004_iter176K.wav shape: (35840,)_loss: 5.13300467
# saved file at ./samples/cycle_A2A_id004_iter176K.wav shape: (35840,)
# Epoch[177]: Input data sampled from 128 A and 64 B audio files: train_data_A (363, 24, 128) train_data_B (363, 24, 128)
# saved file at ./samples/fake_A2B_id005_iter177K.wav shape: (30720,)_loss: 5.71231222
# saved file at ./samples/cycle_A2A_id005_iter177K.wav shape: (30720,)
# Epoch[178]: Input data sampled from 128 A and 64 B audio files: train_data_A (370, 24, 128) train_data_B (370, 24, 128)
# saved file at ./samples/fake_A2B_id006_iter178K.wav shape: (64000,)_loss: 6.63640642
# saved file at ./samples/cycle_A2A_id006_iter178K.wav shape: (64000,)
# Epoch[179]: Input data sampled from 128 A and 64 B audio files: train_data_A (383, 24, 128) train_data_B (383, 24, 128)
# saved file at ./samples/fake_A2B_id007_iter179K.wav shape: (70400,)_loss: 5.45334721
# saved file at ./samples/cycle_A2A_id007_iter179K.wav shape: (70400,)
# Epoch[180]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id008_iter180K.wav shape: (25280,)_loss: 4.95511436
# saved file at ./samples/cycle_A2A_id008_iter180K.wav shape: (25280,)
# Epoch[181]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id009_iter181K.wav shape: (22400,)_loss: 5.29439020
# saved file at ./samples/cycle_A2A_id009_iter181K.wav shape: (22400,)
# Epoch[182]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id010_iter182K.wav shape: (47680,)_loss: 5.60369492
# saved file at ./samples/cycle_A2A_id010_iter182K.wav shape: (47680,)
# Epoch[183]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id011_iter183K.wav shape: (22400,)_loss: 5.91915464
# saved file at ./samples/cycle_A2A_id011_iter183K.wav shape: (22400,)
# Epoch[184]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id012_iter184K.wav shape: (19840,)_loss: 5.45100784
# saved file at ./samples/cycle_A2A_id012_iter184K.wav shape: (19840,)
# Epoch[185]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id013_iter185K.wav shape: (29760,)_loss: 5.79771948
# saved file at ./samples/cycle_A2A_id013_iter185K.wav shape: (29760,)
# Epoch[186]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id014_iter186K.wav shape: (39680,)_loss: 5.39285660
# saved file at ./samples/cycle_A2A_id014_iter186K.wav shape: (39680,)
# Epoch[187]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id015_iter187K.wav shape: (38080,)_loss: 5.40736580
# saved file at ./samples/cycle_A2A_id015_iter187K.wav shape: (38080,)
# Epoch[188]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id016_iter188K.wav shape: (49280,)_loss: 5.67273140
# saved file at ./samples/cycle_A2A_id016_iter188K.wav shape: (49280,)
# Epoch[189]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id017_iter189K.wav shape: (32640,)_loss: 4.84253597
# saved file at ./samples/cycle_A2A_id017_iter189K.wav shape: (32640,)
# Epoch[190]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id018_iter190K.wav shape: (31680,)_loss: 5.14587688
# saved file at ./samples/cycle_A2A_id018_iter190K.wav shape: (31680,)
# Epoch[191]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id019_iter191K.wav shape: (32320,)_loss: 5.72510862
# saved file at ./samples/cycle_A2A_id019_iter191K.wav shape: (32320,)
# Epoch[192]: Input data sampled from 128 A and 64 B audio files: train_data_A (385, 24, 128) train_data_B (385, 24, 128)
# saved file at ./samples/fake_A2B_id020_iter192K.wav shape: (45120,)_loss: 5.40165472
# saved file at ./samples/cycle_A2A_id020_iter192K.wav shape: (45120,)
# Epoch[193]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id021_iter193K.wav shape: (30080,)_loss: 5.51623726
# saved file at ./samples/cycle_A2A_id021_iter193K.wav shape: (30080,)
# Epoch[194]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id022_iter194K.wav shape: (48000,)_loss: 5.11755848
# saved file at ./samples/cycle_A2A_id022_iter194K.wav shape: (48000,)
# Epoch[195]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id023_iter195K.wav shape: (34240,)_loss: 5.58368397
# saved file at ./samples/cycle_A2A_id023_iter195K.wav shape: (34240,)
# Epoch[196]: Input data sampled from 128 A and 64 B audio files: train_data_A (381, 24, 128) train_data_B (381, 24, 128)
# saved file at ./samples/fake_A2B_id024_iter196K.wav shape: (57920,)_loss: 5.40140152
# saved file at ./samples/cycle_A2A_id024_iter196K.wav shape: (57920,)
# Epoch[197]: Input data sampled from 128 A and 64 B audio files: train_data_A (363, 24, 128) train_data_B (363, 24, 128)
# saved file at ./samples/fake_A2B_id025_iter197K.wav shape: (15360,)_loss: 4.98288012
# saved file at ./samples/cycle_A2A_id025_iter197K.wav shape: (15360,)
# Epoch[198]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id026_iter198K.wav shape: (23360,)_loss: 5.20299768
# saved file at ./samples/cycle_A2A_id026_iter198K.wav shape: (23360,)
# Epoch[199]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id027_iter199K.wav shape: (59840,)_loss: 5.31138039
# saved file at ./samples/cycle_A2A_id027_iter199K.wav shape: (59840,)
# Epoch[200]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id028_iter200K.wav shape: (66240,)_loss: 5.63652134
# saved file at ./samples/cycle_A2A_id028_iter200K.wav shape: (66240,)
# Epoch[201]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id029_iter201K.wav shape: (58560,)_loss: 5.08789968
# saved file at ./samples/cycle_A2A_id029_iter201K.wav shape: (58560,)
# Epoch[202]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id030_iter202K.wav shape: (64000,)_loss: 4.95939541
# saved file at ./samples/cycle_A2A_id030_iter202K.wav shape: (64000,)
# Epoch[203]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id031_iter203K.wav shape: (58880,)_loss: 4.87160063
# saved file at ./samples/cycle_A2A_id031_iter203K.wav shape: (58880,)
# Epoch[204]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id032_iter204K.wav shape: (87680,)_loss: 5.35282087
# saved file at ./samples/cycle_A2A_id032_iter204K.wav shape: (87680,)
# Epoch[205]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id033_iter205K.wav shape: (60160,)_loss: 5.39768028
# saved file at ./samples/cycle_A2A_id033_iter205K.wav shape: (60160,)
# Epoch[206]: Input data sampled from 128 A and 64 B audio files: train_data_A (366, 24, 128) train_data_B (366, 24, 128)
# saved file at ./samples/fake_A2B_id034_iter206K.wav shape: (74560,)_loss: 5.36009789
# saved file at ./samples/cycle_A2A_id034_iter206K.wav shape: (74560,)
# Epoch[207]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id035_iter207K.wav shape: (54400,)_loss: 5.39970636
# saved file at ./samples/cycle_A2A_id035_iter207K.wav shape: (54400,)
# Epoch[208]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id036_iter208K.wav shape: (21120,)_loss: 5.46630430
# saved file at ./samples/cycle_A2A_id036_iter208K.wav shape: (21120,)
# Epoch[209]: Input data sampled from 128 A and 64 B audio files: train_data_A (365, 24, 128) train_data_B (365, 24, 128)
# saved file at ./samples/fake_A2B_id037_iter209K.wav shape: (28480,)_loss: 5.41772127
# saved file at ./samples/cycle_A2A_id037_iter209K.wav shape: (28480,)
# Epoch[210]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id038_iter210K.wav shape: (37760,)_loss: 5.13838816
# saved file at ./samples/cycle_A2A_id038_iter210K.wav shape: (37760,)
# Epoch[211]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter211K.wav shape: (141760,)loss: 5.10226345
# saved file at ./samples/cycle_A2A_id039_iter211K.wav shape: (141760,)
# Epoch[212]: Input data sampled from 128 A and 64 B audio files: train_data_A (384, 24, 128) train_data_B (384, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter212K.wav shape: (54400,)_loss: 4.98081160
# saved file at ./samples/cycle_A2A_id040_iter212K.wav shape: (54400,)
# Epoch[213]: Input data sampled from 128 A and 64 B audio files: train_data_A (383, 24, 128) train_data_B (383, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter213K.wav shape: (37120,)_loss: 4.95875216
# saved file at ./samples/cycle_A2A_id041_iter213K.wav shape: (37120,)
# Epoch[214]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id042_iter214K.wav shape: (39360,)_loss: 4.83713579
# saved file at ./samples/cycle_A2A_id042_iter214K.wav shape: (39360,)
# Epoch[215]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id000_iter215K.wav shape: (67520,)_loss: 5.12969017
# saved file at ./samples/cycle_A2A_id000_iter215K.wav shape: (67520,)
# Epoch[216]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id001_iter216K.wav shape: (41920,)_loss: 5.27330971
# saved file at ./samples/cycle_A2A_id001_iter216K.wav shape: (41920,)
# Epoch[217]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id002_iter217K.wav shape: (50560,)_loss: 5.44048452
# saved file at ./samples/cycle_A2A_id002_iter217K.wav shape: (50560,)
# Epoch[218]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id003_iter218K.wav shape: (37440,)_loss: 5.22316647
# saved file at ./samples/cycle_A2A_id003_iter218K.wav shape: (37440,)
# Epoch[219]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id004_iter219K.wav shape: (35840,)_loss: 4.95772362
# saved file at ./samples/cycle_A2A_id004_iter219K.wav shape: (35840,)
# Epoch[220]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id005_iter220K.wav shape: (30720,)_loss: 4.97376204
# saved file at ./samples/cycle_A2A_id005_iter220K.wav shape: (30720,)
# Epoch[221]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id006_iter221K.wav shape: (64000,)_loss: 5.03010750
# saved file at ./samples/cycle_A2A_id006_iter221K.wav shape: (64000,)
# Epoch[222]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id007_iter222K.wav shape: (70400,)_loss: 4.65824938
# saved file at ./samples/cycle_A2A_id007_iter222K.wav shape: (70400,)
# Epoch[223]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id008_iter223K.wav shape: (25280,)_loss: 4.86737490
# saved file at ./samples/cycle_A2A_id008_iter223K.wav shape: (25280,)
# Epoch[224]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id009_iter224K.wav shape: (22400,)_loss: 6.09073925
# saved file at ./samples/cycle_A2A_id009_iter224K.wav shape: (22400,)
# Epoch[225]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id010_iter225K.wav shape: (47680,)_loss: 4.65645504
# saved file at ./samples/cycle_A2A_id010_iter225K.wav shape: (47680,)
# Epoch[226]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id011_iter226K.wav shape: (22400,)_loss: 5.09641647
# saved file at ./samples/cycle_A2A_id011_iter226K.wav shape: (22400,)
# Epoch[227]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id012_iter227K.wav shape: (19840,)_loss: 4.85888529
# saved file at ./samples/cycle_A2A_id012_iter227K.wav shape: (19840,)
# Epoch[228]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id013_iter228K.wav shape: (29760,)_loss: 5.43600559
# saved file at ./samples/cycle_A2A_id013_iter228K.wav shape: (29760,)
# Epoch[229]: Input data sampled from 128 A and 64 B audio files: train_data_A (383, 24, 128) train_data_B (383, 24, 128)
# saved file at ./samples/fake_A2B_id014_iter229K.wav shape: (39680,)_loss: 4.95579433
# saved file at ./samples/cycle_A2A_id014_iter229K.wav shape: (39680,)
# Epoch[230]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id015_iter230K.wav shape: (38080,)_loss: 4.96699619
# saved file at ./samples/cycle_A2A_id015_iter230K.wav shape: (38080,)
# Epoch[231]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id016_iter231K.wav shape: (49280,)_loss: 5.75467587
# saved file at ./samples/cycle_A2A_id016_iter231K.wav shape: (49280,)
# Epoch[232]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id017_iter232K.wav shape: (32640,)_loss: 4.77495575
# saved file at ./samples/cycle_A2A_id017_iter232K.wav shape: (32640,)
# Epoch[233]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id018_iter233K.wav shape: (31680,)_loss: 4.74237728
# saved file at ./samples/cycle_A2A_id018_iter233K.wav shape: (31680,)
# Epoch[234]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id019_iter234K.wav shape: (32320,)_loss: 5.30517626
# saved file at ./samples/cycle_A2A_id019_iter234K.wav shape: (32320,)
# Epoch[235]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id020_iter235K.wav shape: (45120,)_loss: 5.62403202
# saved file at ./samples/cycle_A2A_id020_iter235K.wav shape: (45120,)
# Epoch[236]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id021_iter236K.wav shape: (30080,)_loss: 5.02901649
# saved file at ./samples/cycle_A2A_id021_iter236K.wav shape: (30080,)
# Epoch[237]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id022_iter237K.wav shape: (48000,)_loss: 5.54598856
# saved file at ./samples/cycle_A2A_id022_iter237K.wav shape: (48000,)
# Epoch[238]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id023_iter238K.wav shape: (34240,)_loss: 4.97823477
# saved file at ./samples/cycle_A2A_id023_iter238K.wav shape: (34240,)
# Epoch[239]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id024_iter239K.wav shape: (57920,)_loss: 4.96570539
# saved file at ./samples/cycle_A2A_id024_iter239K.wav shape: (57920,)
# Epoch[240]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id025_iter240K.wav shape: (15360,)_loss: 4.64002132
# saved file at ./samples/cycle_A2A_id025_iter240K.wav shape: (15360,)
# Epoch[241]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id026_iter241K.wav shape: (23360,)_loss: 5.79810810
# saved file at ./samples/cycle_A2A_id026_iter241K.wav shape: (23360,)
# Epoch[242]: Input data sampled from 128 A and 64 B audio files: train_data_A (364, 24, 128) train_data_B (364, 24, 128)
# saved file at ./samples/fake_A2B_id027_iter242K.wav shape: (59840,)_loss: 4.99465513
# saved file at ./samples/cycle_A2A_id027_iter242K.wav shape: (59840,)
# Epoch[243]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id028_iter243K.wav shape: (66240,)_loss: 5.19884396
# saved file at ./samples/cycle_A2A_id028_iter243K.wav shape: (66240,)
# Epoch[244]: Input data sampled from 128 A and 64 B audio files: train_data_A (385, 24, 128) train_data_B (385, 24, 128)
# saved file at ./samples/fake_A2B_id029_iter244K.wav shape: (58560,)_loss: 5.37194300
# saved file at ./samples/cycle_A2A_id029_iter244K.wav shape: (58560,)
# Epoch[245]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id030_iter245K.wav shape: (64000,)_loss: 4.86355782
# saved file at ./samples/cycle_A2A_id030_iter245K.wav shape: (64000,)
# Epoch[246]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id031_iter246K.wav shape: (58880,)_loss: 4.76446009
# saved file at ./samples/cycle_A2A_id031_iter246K.wav shape: (58880,)
# Epoch[247]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id032_iter247K.wav shape: (87680,)_loss: 5.14004278
# saved file at ./samples/cycle_A2A_id032_iter247K.wav shape: (87680,)
# Epoch[248]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id033_iter248K.wav shape: (60160,)_loss: 5.24938202
# saved file at ./samples/cycle_A2A_id033_iter248K.wav shape: (60160,)
# Epoch[249]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id034_iter249K.wav shape: (74560,)_loss: 4.45560455
# saved file at ./samples/cycle_A2A_id034_iter249K.wav shape: (74560,)
# Epoch[250]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id035_iter250K.wav shape: (54400,)_loss: 4.84394073
# saved file at ./samples/cycle_A2A_id035_iter250K.wav shape: (54400,)
# Epoch[251]: Input data sampled from 128 A and 64 B audio files: train_data_A (381, 24, 128) train_data_B (381, 24, 128)
# saved file at ./samples/fake_A2B_id036_iter251K.wav shape: (21120,)_loss: 5.34768534
# saved file at ./samples/cycle_A2A_id036_iter251K.wav shape: (21120,)
# Epoch[252]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id037_iter252K.wav shape: (28480,)_loss: 4.66537952
# saved file at ./samples/cycle_A2A_id037_iter252K.wav shape: (28480,)
# Epoch[253]: Input data sampled from 128 A and 64 B audio files: train_data_A (383, 24, 128) train_data_B (383, 24, 128)
# saved file at ./samples/fake_A2B_id038_iter253K.wav shape: (37760,)_loss: 4.72451448
# saved file at ./samples/cycle_A2A_id038_iter253K.wav shape: (37760,)
# Epoch[254]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter254K.wav shape: (141760,)loss: 4.70578957
# saved file at ./samples/cycle_A2A_id039_iter254K.wav shape: (141760,)
# Epoch[255]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter255K.wav shape: (54400,)_loss: 5.50511932
# saved file at ./samples/cycle_A2A_id040_iter255K.wav shape: (54400,)
# Epoch[256]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter256K.wav shape: (37120,)_loss: 5.07648897
# saved file at ./samples/cycle_A2A_id041_iter256K.wav shape: (37120,)
# Epoch[257]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id042_iter257K.wav shape: (39360,)_loss: 5.18203497
# saved file at ./samples/cycle_A2A_id042_iter257K.wav shape: (39360,)
# Epoch[258]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id000_iter258K.wav shape: (67520,)_loss: 4.75331163
# saved file at ./samples/cycle_A2A_id000_iter258K.wav shape: (67520,)
# Epoch[259]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id001_iter259K.wav shape: (41920,)_loss: 4.83472538
# saved file at ./samples/cycle_A2A_id001_iter259K.wav shape: (41920,)
# Epoch[260]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id002_iter260K.wav shape: (50560,)_loss: 5.25810051
# saved file at ./samples/cycle_A2A_id002_iter260K.wav shape: (50560,)
# Epoch[261]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id003_iter261K.wav shape: (37440,)_loss: 4.85661221
# saved file at ./samples/cycle_A2A_id003_iter261K.wav shape: (37440,)
# Epoch[262]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id004_iter262K.wav shape: (35840,)_loss: 5.14864063
# saved file at ./samples/cycle_A2A_id004_iter262K.wav shape: (35840,)
# Epoch[263]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id005_iter263K.wav shape: (30720,)_loss: 5.07889366
# saved file at ./samples/cycle_A2A_id005_iter263K.wav shape: (30720,)
# Epoch[264]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id006_iter264K.wav shape: (64000,)_loss: 5.08434248
# saved file at ./samples/cycle_A2A_id006_iter264K.wav shape: (64000,)
# Epoch[265]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id007_iter265K.wav shape: (70400,)_loss: 4.94681644
# saved file at ./samples/cycle_A2A_id007_iter265K.wav shape: (70400,)
# Epoch[266]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id008_iter266K.wav shape: (25280,)_loss: 5.18936443
# saved file at ./samples/cycle_A2A_id008_iter266K.wav shape: (25280,)
# Epoch[267]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id009_iter267K.wav shape: (22400,)_loss: 4.70936728
# saved file at ./samples/cycle_A2A_id009_iter267K.wav shape: (22400,)
# Epoch[268]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id010_iter268K.wav shape: (47680,)_loss: 4.55077028
# saved file at ./samples/cycle_A2A_id010_iter268K.wav shape: (47680,)
# Epoch[269]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id011_iter269K.wav shape: (22400,)_loss: 4.47949791
# saved file at ./samples/cycle_A2A_id011_iter269K.wav shape: (22400,)
# Epoch[270]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id012_iter270K.wav shape: (19840,)_loss: 4.75213814
# saved file at ./samples/cycle_A2A_id012_iter270K.wav shape: (19840,)
# Epoch[271]: Input data sampled from 128 A and 64 B audio files: train_data_A (375, 24, 128) train_data_B (375, 24, 128)
# saved file at ./samples/fake_A2B_id013_iter271K.wav shape: (29760,)_loss: 4.70271397
# saved file at ./samples/cycle_A2A_id013_iter271K.wav shape: (29760,)
# Epoch[272]: Input data sampled from 128 A and 64 B audio files: train_data_A (381, 24, 128) train_data_B (381, 24, 128)
# saved file at ./samples/fake_A2B_id014_iter272K.wav shape: (39680,)_loss: 4.37955999
# saved file at ./samples/cycle_A2A_id014_iter272K.wav shape: (39680,)
# Epoch[273]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id015_iter273K.wav shape: (38080,)_loss: 4.68479252
# saved file at ./samples/cycle_A2A_id015_iter273K.wav shape: (38080,)
# Epoch[274]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id016_iter274K.wav shape: (49280,)_loss: 4.62975264
# saved file at ./samples/cycle_A2A_id016_iter274K.wav shape: (49280,)
# Epoch[275]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id017_iter275K.wav shape: (32640,)_loss: 4.49130011
# saved file at ./samples/cycle_A2A_id017_iter275K.wav shape: (32640,)
# Epoch[276]: Input data sampled from 128 A and 64 B audio files: train_data_A (381, 24, 128) train_data_B (381, 24, 128)
# saved file at ./samples/fake_A2B_id018_iter276K.wav shape: (31680,)_loss: 4.92827415
# saved file at ./samples/cycle_A2A_id018_iter276K.wav shape: (31680,)
# Epoch[277]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id019_iter277K.wav shape: (32320,)_loss: 4.51577950
# saved file at ./samples/cycle_A2A_id019_iter277K.wav shape: (32320,)
# Epoch[278]: Input data sampled from 128 A and 64 B audio files: train_data_A (379, 24, 128) train_data_B (379, 24, 128)
# saved file at ./samples/fake_A2B_id020_iter278K.wav shape: (45120,)_loss: 4.68983173
# saved file at ./samples/cycle_A2A_id020_iter278K.wav shape: (45120,)
# Epoch[279]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id021_iter279K.wav shape: (30080,)_loss: 4.81272554
# saved file at ./samples/cycle_A2A_id021_iter279K.wav shape: (30080,)
# Epoch[280]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id022_iter280K.wav shape: (48000,)_loss: 4.56224728
# saved file at ./samples/cycle_A2A_id022_iter280K.wav shape: (48000,)
# Epoch[281]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id023_iter281K.wav shape: (34240,)_loss: 4.70998335
# saved file at ./samples/cycle_A2A_id023_iter281K.wav shape: (34240,)
# Epoch[282]: Input data sampled from 128 A and 64 B audio files: train_data_A (370, 24, 128) train_data_B (370, 24, 128)
# saved file at ./samples/fake_A2B_id024_iter282K.wav shape: (57920,)_loss: 5.23920202
# saved file at ./samples/cycle_A2A_id024_iter282K.wav shape: (57920,)
# Epoch[283]: Input data sampled from 128 A and 64 B audio files: train_data_A (374, 24, 128) train_data_B (374, 24, 128)
# saved file at ./samples/fake_A2B_id025_iter283K.wav shape: (15360,)_loss: 4.60017967
# saved file at ./samples/cycle_A2A_id025_iter283K.wav shape: (15360,)
# Epoch[284]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id026_iter284K.wav shape: (23360,)_loss: 4.19158602
# saved file at ./samples/cycle_A2A_id026_iter284K.wav shape: (23360,)
# Epoch[285]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id027_iter285K.wav shape: (59840,)_loss: 5.21115208
# saved file at ./samples/cycle_A2A_id027_iter285K.wav shape: (59840,)
# Epoch[286]: Input data sampled from 128 A and 64 B audio files: train_data_A (368, 24, 128) train_data_B (368, 24, 128)
# saved file at ./samples/fake_A2B_id028_iter286K.wav shape: (66240,)_loss: 4.59020281
# saved file at ./samples/cycle_A2A_id028_iter286K.wav shape: (66240,)
# Epoch[287]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id029_iter287K.wav shape: (58560,)_loss: 4.66798449
# saved file at ./samples/cycle_A2A_id029_iter287K.wav shape: (58560,)
# Epoch[288]: Input data sampled from 128 A and 64 B audio files: train_data_A (378, 24, 128) train_data_B (378, 24, 128)
# saved file at ./samples/fake_A2B_id030_iter288K.wav shape: (64000,)_loss: 5.55319118
# saved file at ./samples/cycle_A2A_id030_iter288K.wav shape: (64000,)
# Epoch[289]: Input data sampled from 128 A and 64 B audio files: train_data_A (371, 24, 128) train_data_B (371, 24, 128)
# saved file at ./samples/fake_A2B_id031_iter289K.wav shape: (58880,)_loss: 4.75058794
# saved file at ./samples/cycle_A2A_id031_iter289K.wav shape: (58880,)
# Epoch[290]: Input data sampled from 128 A and 64 B audio files: train_data_A (381, 24, 128) train_data_B (381, 24, 128)
# saved file at ./samples/fake_A2B_id032_iter290K.wav shape: (87680,)_loss: 4.79962206
# saved file at ./samples/cycle_A2A_id032_iter290K.wav shape: (87680,)
# Epoch[291]: Input data sampled from 128 A and 64 B audio files: train_data_A (377, 24, 128) train_data_B (377, 24, 128)
# saved file at ./samples/fake_A2B_id033_iter291K.wav shape: (60160,)_loss: 4.84691191
# saved file at ./samples/cycle_A2A_id033_iter291K.wav shape: (60160,)
# Epoch[292]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id034_iter292K.wav shape: (74560,)_loss: 4.87948132
# saved file at ./samples/cycle_A2A_id034_iter292K.wav shape: (74560,)
# Epoch[293]: Input data sampled from 128 A and 64 B audio files: train_data_A (380, 24, 128) train_data_B (380, 24, 128)
# saved file at ./samples/fake_A2B_id035_iter293K.wav shape: (54400,)_loss: 4.57665586
# saved file at ./samples/cycle_A2A_id035_iter293K.wav shape: (54400,)
# Epoch[294]: Input data sampled from 128 A and 64 B audio files: train_data_A (369, 24, 128) train_data_B (369, 24, 128)
# saved file at ./samples/fake_A2B_id036_iter294K.wav shape: (21120,)_loss: 4.38788366
# saved file at ./samples/cycle_A2A_id036_iter294K.wav shape: (21120,)
# Epoch[295]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id037_iter295K.wav shape: (28480,)_loss: 4.60543442
# saved file at ./samples/cycle_A2A_id037_iter295K.wav shape: (28480,)
# Epoch[296]: Input data sampled from 128 A and 64 B audio files: train_data_A (376, 24, 128) train_data_B (376, 24, 128)
# saved file at ./samples/fake_A2B_id038_iter296K.wav shape: (37760,)_loss: 4.89861202
# saved file at ./samples/cycle_A2A_id038_iter296K.wav shape: (37760,)
# Epoch[297]: Input data sampled from 128 A and 64 B audio files: train_data_A (373, 24, 128) train_data_B (373, 24, 128)
# saved file at ./samples/fake_A2B_id039_iter297K.wav shape: (141760,)loss: 4.51875591
# saved file at ./samples/cycle_A2A_id039_iter297K.wav shape: (141760,)
# Epoch[298]: Input data sampled from 128 A and 64 B audio files: train_data_A (367, 24, 128) train_data_B (367, 24, 128)
# saved file at ./samples/fake_A2B_id040_iter298K.wav shape: (54400,)_loss: 4.43989182
# saved file at ./samples/cycle_A2A_id040_iter298K.wav shape: (54400,)
# Epoch[299]: Input data sampled from 128 A and 64 B audio files: train_data_A (372, 24, 128) train_data_B (372, 24, 128)
# saved file at ./samples/fake_A2B_id041_iter299K.wav shape: (37120,)_loss: 4.53002644
# saved file at ./samples/cycle_A2A_id041_iter299K.wav shape: (37120,)
#  [*] Training finished!1000] time: 65395.0584 d_loss: 0.00001110, g_loss: 4.35443974
#  [*] Reading checkpoints...
# INFO:tensorflow:Restoring parameters from checkpoint/CYCLE_neu_sad_lsgan/CYCLE.model-300000
#  [*] Success to read CYCLE.model-300000
#  [*] Load SUCCESS
# std_log_src: 0.28322630020087086 std_log_target 0.22782205878435718
#  [*] Testing finished!s B2A: [14/14]
